# %% [markdown]
# # 0. Enter username (output folder will made for this name)

# %%
import time
notebook_start_time = time.time()

# %%
user_name = "user_name"

# %% [markdown]
# # 1. Basic prompt template of LangChain enviroment

# %%
template = """
You are a data analyst specializing in nano-toxicity.
Your task is extracting data about the physicochemical and cytotoxic properties of nanomaterials used in the research paper.
Use the following pieces of instruction and format to answer the user's questions.
Don't be lazy.
Be very strict and answer the question very accurate and scientific manner.
If data is not specified in the paper, just answer 'None'.
Do not use a full sentence.
Context: {context}
Question: {question}
Format instruction: {format_instructions}
"""

# %% [markdown]
# # 2. Material data extraction prompt

# %%
q_mat = """
Just answer with following format: 'Nanomaterial name (Nanomaterial type)'. Do not use a full sentence.
Question: What nanoparticles were used in the characterization experiments in the research paper? Refer to the following descriptions.
Description 1. Provide the nanoparticles that were used for core size(i.e. primary size, nominal size) or hydrodynamic size(i.e. Z-average size) or surface charge(i.e. zeta potential) or surface area in the research paper.
Description 2. Provide information on all the nanoparticles actually used in the authors' experiments, Do not include nanoparticles used in other papers (i.e., mentioned in the reference) in your answer.
Description 3. If there were multiple nanoparticles of the same type, the author would have named them differently. What did the author name them?
Description 4. Write the name of the nanoparticle followed by its type in chemical formula within parentheses.
Description 5. Several examples of the format.
-Written in the document: Al2O3, ZnO, SiO2, Fe2O3 (normal form), Response: Al2O3 (Al2O3), ZnO (ZnO), SiO2 (SiO2), Fe2O3 (Fe2O3).
-Written in the document: T10, T100 (labeled differently according to 'size'), Response: T10 (TiO2), T100 (TiO2).
-Written in the document: ZnAc, ZnChl (ZnO-Acetate, ZnO-Chloride; labeled differently according to 'chemical'), Response: ZnAc (ZnO), ZnChl (ZnO).
-Written in the document: TiO2-PVP, TiO2-Citrate (labeled differently according to 'coating'), Response: TiO2-PVP (TiO2), TiO2-Citrate (TiO2).
-Written in the document: P25, ST-21 (labeled differently according to 'manufacturer'), Response: P25 (TiO2), ST-21 (TiO2).
-Written in the document: CuO-USA, CuO-UK (labeled differently according to 'location'), Response: CuO-USA (CuO), CuO-UK (CuO).
Description 6. Do not omit the information.
Description 7. Do not write 'NP' or 'nanoparticles' followed by nanoparticles'name
"""

# %% [markdown]
# # 3. PChem/Tox data extraction prompt
# - Pchem
# - Tox

# %%
import pprint
from typing import Any, Dict
import datetime
from pytz import timezone

import pandas as pd
from langchain.output_parsers import PydanticOutputParser
#from langchain.output_parsers import PandasDataFrameParser

from langchain.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field, validator

class pchem_product_info(BaseModel):
    mat_name: str = Field(description="Question: What nanoparticles were used in the characterization experiments in the research paper? Refer to the following descriptions. Description 0. Do not include metal nanoparticles such as Silver (Ag) or Gold (Au). 1. Provide the nanoparticles that were used for core size(i.e. primary size, nominal size) or hydrodynamic size(i.e. Z-average size) or surface charge(i.e. zeta potential) or surface area in the research paper. Description 2. Provide information on all the nanoparticles actually used in the authors' experiments. Do not include nanoparticles used in other papers (i.e., mentioned in the reference) in your answer. Description 3. If there were multiple nanoparticles of the same type, the author would have named them differently. What did the author name them? Description 4. Write the name of the nanoparticle followed by its type in chemical formula within parentheses.   Description 5. Several examples of the format. -Written in the document: Al2O3 NPs, ZnO, SiO2, Fe2O3 (normal form), Response: Al2O3 (Al2O3), ZnO (ZnO), SiO2 (SiO2), Fe2O3 (Fe2O3). -Written in the document: T10, T100 (labeled differently according to 'size'), Response: T10 (TiO2), T100 (TiO2). -Written in the document: ZnAc, ZnChl (ZnO-Acetate, ZnO-Chloride; labeled differently according to 'chemical'), Response: ZnAc (ZnO), ZnChl (ZnO). -Written in the document: TiO2-PVP, TiO2-Citrate (labeled differently according to 'coating'), Response: TiO2-PVP (TiO2), TiO2-Citrate (TiO2). -Written in the document: P25, Nanofilament (labeled differently according to 'manufacturer'), Response: P25 (TiO2), Nanofilament (TiO2). -Written in the document: CuO-USA, CuO-UK (labeled differently according to 'location'), Response: CuO-USA (CuO), CuO-UK (CuO). Description 6. Do not omit the information. Description 7. Do not write 'NP' or 'nanoparticles' followed by nanoparticles'name")
    def to_dict(self):
        return {"mat_name": self.mat_name}

class pchem_mat_synthesis(BaseModel):
    mat_synthesis: str = Field(description="The following nanoparticles were synthesized by researcher? or commercially available? If nanoparticles were synthesized, just answer 'Synthesized'. If nanoparticles were commercially available, just answer 'Commercially available (with cat# or product # in parentheses).'")
    def to_dict(self):
        return {"mat_synthesis": self.mat_synthesis}

class pchem_core_size(BaseModel):
    mat_core_size: str = Field(description="What is the value of core size or core size distribution (i.e. primary size, nominal size) of each material? Refer to the following format to answer. 0. TEM, SEM, AFM size. 1. Do not include unit. 2. Do not use a full sentence. 3. If there is no value, assign 'None'. 4. Do not include calculated size. 5. If the values are represented as a range, they are represented in the following format: value1-value2. ex) 50-100. 6. If the values are represented with an error rate '±', they are represented in the following format: value±error rate. ex) 35±10.")
    mat_core_size_measurement_method: str = Field(description="What measurement method is used for measure core size (i.e., primary size)? 1. transmission electron microscopy (TEM) should be selected first, followed by scanning electron microscopy (SEM), atomic force microscopy (AFM), and X-ray diffraction (XRD) in cases where multiple methods are available. 2. If the measurement mehod is not present type 'None'. 3. please use abbreviation form such as TEM, SEM, XRD.")
    mat_core_size_source: str = Field(description="Is the core size data sourced from the author's own experiment, manufacturer specifications, a reference paper, or is it not provided? Just answer four types. Format: Experiment, Manufacturer, Reference, Not specified")
    def to_dict(self):
        return {"mat_core_size": self.mat_core_size, "mat_core_size_measurement_method": self.mat_core_size_measurement_method, "mat_core_size_source": self.mat_core_size_source}

class pchem_hydrodynamic_size(BaseModel):
    mat_hydrodynamic_size: str = Field(description="What is the value of hydrodynamic size (i.e., Z-average size, size in media) of each material? Please provide details on the sizes under various conditions or in different media. 0. DLS size. 1. Do not include unit. 2. Do not include an explanation about hydrodynamic size. Just give me the value. 3. Do not use a full sentence. 4. If there is no value, assign 'None'. 5. If multiple values exist for each material, divide the value using ';', add parentheses after the value, and write the conditions in the parentheses. 6. Please refer to the following format when you write down the conditions in parentheses. Format: [Classification: detailed conditions]. ex) 50 (Solvent: water); 100 (Solvent: medium), 30 (Time: 2 h); 50 (Time: 24 h). Kind of Classification: Solvent, Time, Concentration, pH.7. If there are both water and culture media conditions, only the culture media condition is selected. However, if there are only conditions taken in water, select conditions taken in water. If t 8. If the values are represented as a range, they are represented in the following format: value1-value2. ex) 50-100. 9. If the values are represented with an error rate '±', they are represented in the following format: value±error rate. ex) 35±10.")
    mat_hydrodynamic_size_measurement_method: str = Field(description="What measurement method is used for measure hydrodynamic size (i.e., aggregates size, Z-average size)?  1. Dynamic light scattering (DLS) or Nanoparticle tracking analysis (NTA) should be selected first, followed by FCS in cases where multiple methods are available. 2. If the measurement mehod is not present type 'None'. 3. please use abbreviation form such as DLS, NTA.")
    mat_hydrodynamic_size_source: str = Field(description="Is the hydrodynamic size data sourced from the author's own experiment, manufacturer specifications, a reference paper, or is it not provided? Just answer four types. Format: Experiment, Manufacturer, Reference, Not specified")
    def to_dict(self):
        return {"mat_hydrodynamic_size": self.mat_hydrodynamic_size, "mat_hydrodynamic_size_measurement_method": self.mat_hydrodynamic_size_measurement_method, "mat_hydrodynamic_size_source": self.mat_hydrodynamic_size_source}

class pchem_surface_charge(BaseModel):
    mat_surface_charge: str = Field(description="What is the value of surface charge (i.e., Zeta potential) of each material? Please provide details on the sizes under various conditions or in different media. 1. Do not include unit. 2. Do not include an explanation about hydrodynamic size. Just give me the value. 3. Do not use a full sentence. 4. If there is no value, assign 'None'. 5. If multiple values exist for each material, divide the value using ';', add parentheses after the value, and write the conditions in the parentheses. 6. Please refer to the following format when you write down the conditions in parentheses. Format: [Classification: detailed conditions]. ex) -10 (Solvent: water); 21 (Solvent: medium), 30 (Time: 2 h); 50 (Time: 24 h). Kind of Classification: Solvent, Time, Concentration, pH. 7. If the values are represented as a range, they are represented in the following format: value1-value2. ex) 50-100. 8. If the values are represented with an error rate '±', they are represented in the following format: value±error rate. ex) 35±10. 9. If there are both water and culture media conditions, only the culture media condition is selected. However, if there are only conditions taken in water, select conditions taken in water.")
    mat_surface_charge_measurement_method: str = Field(description="What measurement method is used for measure surface charge (i.e., Zeta potential)?  1. IF surface charge data exist, just answer Zeta potential. 2. Format to anwser: Zeta potential.")
    mat_surface_charge_source: str = Field(description="Is the hydrodynamic size data sourced from the author's own experiment, manufacturer specifications, a reference paper, or is it not provided? Just answer four types. Format: Experiment, Manufacturer, Reference, Not specified")
    def to_dict(self):
        return {"mat_surface_charge": self.mat_surface_charge, "mat_surface_charge_measurement_method": self.mat_surface_charge_measurement_method, "mat_surface_charge_source": self.mat_surface_charge_source}

class pchem_surface_area(BaseModel):
    mat_surface_area: str = Field(description="What is the value of surface area of each material? Refer to the following format to answer. 1. Do not include unit. 2. Do not use a full sentence. 3. If there is no value, assign 'None'. 4. Do not include calculated size. 5. If the values are represented as a range, they are represented in the following format: value1-value2. ex) 50-100. 6. If the values are represented with an error rate '±', they are represented in the following format: value±error rate. ex) 35±10.")
    mat_surface_area_measurement_method: str = Field(description="What measurement method is used for measure surface area (i.e., SSA)?  1. Brunauer-Emmett-Teller (BET) method is most common measurement method. 3. please use abbreviation form such as BET.")
    mat_surface_area_source: str = Field(description="Is the hydrodynamic size data sourced from the author's own experiment, manufacturer specifications, a reference paper, or is it not provided? Just answer four types. Format: Experiment, Manufacturer, Reference, Not specified")
    def to_dict(self):
        return {"mat_surface_area": self.mat_surface_area, "mat_surface_area_measurement_method": self.mat_surface_area_measurement_method, "mat_surface_area_source": self.mat_surface_area_source}

# %%
class tox_info(BaseModel):
    cell_type: str = Field(description="What cell lines were used in the cell viability assay? 1. Do not use a full sentence. 2. Please provide the abbreviation form of the cell name. ex) A549, THP-1, MRC-5, EA.hy926, BEAS-2B, HaCaT, L929, U87, etc. 3. If multiple cell lines were used, divide the value using ';'. ex) A549; THP-1; MRC-5.")
    cell_species: str = Field(description="What species the cell line originated from? 1. Do not use a full sentence. 2. Please refer to the following form. ex) Human, Rabbit, Mouse, Pig, etc. 3. If multiple cell lines were used and their species are different,  divide the value using ';' and write the name of the cell species followed by its cell type within parentheses. ex) Human (A549); Mouse (L929).")
    cell_organ: str = Field(description="What organ the cell line originated from? 1. Do not use a full sentence. 2. Please refer to the following form. ex) Lung, Breast, Kidney, Brain, Liver, Bronchial tube, Prostate, Spleen, etc. 3. If multiple cell lines were used and their organs are different, divide the value using ';' and write the name of the cell species followed by its cell type within parentheses. ex) Lung (A549); Fibroblast (L929).")
    cell_assay: str = Field(description="Which cell viability assays or cytotoxicity assay were conducted in this paper? 1. Do not use a full sentence. 2. Only reference the following cell viability assays, and if none, assign as 'None'. 2. Please refer to the following form. ex) CCK-8, MTT, MTS, WST, Alamar blue, CellTiter-Glo, Neutral Red, NRU, Trypan blue, XTT, Calcein-AM, BrdU, EdU, Propidium iodide, Hoechst33342 assays. 3. If multiple cell viability assays were used, divide the value using ';'. ex) MTT; MTS; CCK-8.")
    cell_classification: str = Field(description="Please determine the cell type: whether it is a normal cell or a cancer cell? 1. Do not use a full sentence. 2. Just answer, 'Normal' or 'Cancer'.")
    def to_dict(self):
        return {"cell_type": self.cell_type, "cell_species": self.cell_species, "cell_organ": self.cell_organ, "cell_assay": self.cell_assay,"cell_classification": self.cell_classification}

# %% [markdown]
# # 4. Connect LangChain with Zotero
# - Zotero collection cionfiguration
# - Set directory of output and zotero pdf download
# - Extract data from Zotero
# - Get PDF file list and IDs

# %%
import time
embedding_start_time = time.time()

# %%
##Zotero collection configuration

import os
from os.path import join, basename, splitext
import subprocess
from glob import glob
from shutil import copy
from random import shuffle, seed

from pyzotero import zotero

zot = zotero.Zotero(library_id, 'library_type', 'zotero_api_key') ## fill zotero.Zoter(library_id, library_type, zotero_api_key)

collections = {c['data']['name']: c for c in zot.collections()}

collection_names = []
for key, value in collections.items():
    #print(key)
    collection_names.append(key)

collection_names
# Out:
# ['remove123456',
#  'remove12345',
#  'remove123',
#  'PchemScore_1',
#  'oxide af filter5',
#  'oxide af filter3',
#  'oxide af filter2',
#  'pmfilter',
#  'oxide af a',
#  'oxide af filter1',
#  'oxide af filter',
#  'WOS 8',
#  'WOS 7',
#  'WOS 6',
#  'WOS 5',
#  'WOS 4',
#  'WOS 3',
#  'WOS 1',
#  'WOS 2',
#  'WOS 0',
#  'PUBMED 9',
#  'PUBMED 8',
#  'PUBMED 7',
#  'PUBMED 6',
#  'PUBMED 2',
#  'PUBMED 1',
#  'PUBMED 5',
#  'PUBMED 4',
#  'PUBMED 3',
#  'PUBMED 0',
#  'testa',
#  'new pdf',
#  'Oxide af 2018 WOS',
#  'Oxide af 2018 PUBMED',
#  'Ha 1a-1',
#  'Metal oxide after 2018 wos',
#  'Metal oxide after 2018 pubmed',
#  'test1',
#  'Metal External dataset',
#  'ddd',
#  'Trinh_test',
#  'External dataset',
#  'Ha 1d',
#  'Ha 1c',
#  'Ha 1b',
#  'Ha 1a',
#  'Ha 3b',
#  '2025_DB',
#  'TrinhB',
#  'Ha 3a',
#  'Ha 2',
#  'TrinhA',
#  'training set oxide 3',
#  'training set metal 2',
#  'training set oxide 2',
#  'training set metal',
#  'test set for chatGPT',
#  'traning set for chatGPT',
#  'Ha IIIa',
#  'Ha II',
#  'Ha I',
#  'Xiao Metal',
#  'Ha Oxide 2018',
#  'Xiao Oxide',
#  'Trinh Metal 2018',
#  'kriss.s2nano.org : after 2018',
#  'qntr.s2nno.org : before2018',
#  'prof collection',
#  'training set oxide',
#  'automation for Nanotox']

# %%
selected_collection = "enter_collection_name" # copy and pase collection name
pdf_folder = "/home/pdf_pdf" + selected_collection.replace(" ", "_")
print("PDF 파일들은 " + pdf_folder + "에 저장됩니다.")
# Out:
# PDF 파일들은 /home/pdf_pdfHa_3b에 저장됩니다.

# %%
## PDF 파일 폴더와 output 폴더 설정

import os

def create_folder(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder created at {folder_path}")
    else:
        print(f"Folder already exists at {folder_path}")

output_folder = "output_" + user_name
create_folder(output_folder)
create_folder(pdf_folder)
# Out:
# Folder already exists at output_HEY20241118-Eunyong Ha-reproducibility
# Folder already exists at /home/pdf_pdfHa_3b

# %%
## extract collection data from zotero

import os
from os.path import join, basename, splitext
import subprocess
from glob import glob
from shutil import copy
from random import shuffle, seed

from pyzotero import zotero
zot = zotero.Zotero(library_id, 'library_type', 'zotero_api_key') ## fill zotero.Zoter(library_id, library_type, zotero_api_key)

collections = {c['data']['name']: c for c in zot.collections()}
collection = collections[selected_collection]
key = collection['key']

items = [d for d in zot.everything(zot.collection_items(key))]

pdf_dict = {}
for item in items:
    pdf_dict[item['data']['key']] = item['data']['title']

### if there is 'title' error use this code
#for item in items:
#    # Check if the 'title' key exists in the item['data']
#    if 'title' in item['data']:
#        pdf_dict[item['data']['key']] = item['data']['title']
#    else:
#        print(f"Item {item['data']['key']} does not have a title.")

# Iterate over items in the collection
for item in items:
    title = item['data'].get('title', 'No Title')
    print(f"\nProcessing item: {title}")

    # Ensure we're not processing non-attachment items
    if item['data'].get('itemType') != 'attachment':
        try:
            children = [c for c in zot.children(item['key'])]
            print(f"Found {len(children)} children for item '{title}'")

            # Check for PDFs among the children
            pdfs = [c for c in children if c['data'].get('contentType') == 'application/pdf']

            if not children:
                print(f"Missing documents for: {title}")
            elif not pdfs:
                print(f"No PDFs found for: {title}")
            elif len(pdfs) > 1:
                print(f"Too many PDFs for: {title}")
            else:
                doc = pdfs[0]
                print(f"PDF found: {doc['data']['filename']}")

                pdf_file_path = os.path.join(pdf_folder, f"{doc['key']}.pdf")

                # Check if the PDF already exists, and download if it doesn't
                if not os.path.exists(pdf_file_path):
                    zot.dump(doc['key'], pdf_file_path, pdf_folder)
                    print(f"{pdf_file_path} is downloaded.")
                else:
                    print(f"{pdf_file_path} already exists.")

        except Exception as e:
            print(f"Error processing item {title}: {e}")
    else:
        print(f"Skipped non-PDF entry: {title}")
# Out:
# Processing item: Michael Berg 등 - 2013 - Comparative cytological responses of lung epitheli.pdf
# Skipped non-PDF entry: Michael Berg 등 - 2013 - Comparative cytological responses of lung epitheli.pdf
#
# Processing item: Hsiao 그리고 Huang - 2011 - Effects of various physicochemical characteristics.pdf
# Skipped non-PDF entry: Hsiao 그리고 Huang - 2011 - Effects of various physicochemical characteristics.pdf
#
# Processing item: Reactive oxygen species mediated DNA damage in human lung alveolar epithelial (A549) cells from exposure to non-cytotoxic MFI-type zeolite nanoparticles
# Found 1 children for item 'Reactive oxygen species mediated DNA damage in human lung alveolar epithelial (A549) cells from exposure to non-cytotoxic MFI-type zeolite nanoparticles'
# PDF found: 23103338.pdf
# /home/pdf_pdfHa_3b/EXQ8I7IY.pdf already exists.
#
# Processing item: 23103338
# Skipped non-PDF entry: 23103338
#
# Processing item: Comparative cytological responses of lung epithelial and pleural mesothelial cells following in vitro exposure to nanoscale SiO2
# Found 1 children for item 'Comparative cytological responses of lung epithelial and pleural mesothelial cells following in vitro exposure to nanoscale SiO2'
# PDF found: Michael Berg 등 - 2013 - Comparative cytological responses of lung epitheli.pdf
# /home/pdf_pdfHa_3b/6Z5K86RQ.pdf already exists.
#
# Processing item: 23274916
# Skipped non-PDF entry: 23274916
#
# Processing item: In vitro cytotoxicity and genotoxicity studies of titanium dioxide (TiO2) nanoparticles in Chinese hamster lung fibroblast cells
# Found 1 children for item 'In vitro cytotoxicity and genotoxicity studies of titanium dioxide (TiO2) nanoparticles in Chinese hamster lung fibroblast cells'
# PDF found: 23274916.pdf
# /home/pdf_pdfHa_3b/HVPYYSLW.pdf already exists.
#
# Processing item: Role of size and surface area for pro-inflammatory responses to silica nanoparticles in epithelial lung cells: Importance of exposure conditions
# Found 1 children for item 'Role of size and surface area for pro-inflammatory responses to silica nanoparticles in epithelial lung cells: Importance of exposure conditions'
# PDF found: Skuland 등 - 2014 - Role of size and surface area for pro-inflammatory.pdf
# /home/pdf_pdfHa_3b/USNLP6MR.pdf already exists.
#
# Processing item: Skuland 등 - 2014 - Role of size and surface area for pro-inflammatory.pdf
# Skipped non-PDF entry: Skuland 등 - 2014 - Role of size and surface area for pro-inflammatory.pdf
#
# Processing item: Titanium dioxide induces apoptotic cell death through reactive oxygen species-mediated Fas upregulation and Bax activation
# Found 1 children for item 'Titanium dioxide induces apoptotic cell death through reactive oxygen species-mediated Fas upregulation and Bax activation'
# PDF found: Lee 등 - 2012 - Titanium dioxide induces apoptotic cell death thro.pdf
# /home/pdf_pdfHa_3b/95ASP9SZ.pdf already exists.
#
# Processing item: Lee 등 - 2012 - Titanium dioxide induces apoptotic cell death thro.pdf
# Skipped non-PDF entry: Lee 등 - 2012 - Titanium dioxide induces apoptotic cell death thro.pdf
#
# Processing item: Xiong 등 - 2013 - Size influences the cytotoxicity of poly (lactic-c.pdf
# Skipped non-PDF entry: Xiong 등 - 2013 - Size influences the cytotoxicity of poly (lactic-c.pdf
#
# Processing item: Size influences the cytotoxicity of poly (lactic-co-glycolic acid) (PLGA) and titanium dioxide (TiO(2)) nanoparticles
# Found 1 children for item 'Size influences the cytotoxicity of poly (lactic-co-glycolic acid) (PLGA) and titanium dioxide (TiO(2)) nanoparticles'
# PDF found: Xiong 등 - 2013 - Size influences the cytotoxicity of poly (lactic-c.pdf
# /home/pdf_pdfHa_3b/YNQITCKF.pdf already exists.
#
# Processing item: Cytotoxicity, permeability, and inflammation of metal oxide nanoparticles in human cardiac microvascular endothelial cells: Cytotoxicity, permeability, and inflammation of metal oxide nanoparticles
# Found 1 children for item 'Cytotoxicity, permeability, and inflammation of metal oxide nanoparticles in human cardiac microvascular endothelial cells: Cytotoxicity, permeability, and inflammation of metal oxide nanoparticles'
# PDF found: Sun 등 - 2011 - Cytotoxicity, permeability, and inflammation of me.pdf
# /home/pdf_pdfHa_3b/SKCFUKGT.pdf already exists.
#
# Processing item: Sun 등 - 2011 - Cytotoxicity, permeability, and inflammation of me.pdf
# Skipped non-PDF entry: Sun 등 - 2011 - Cytotoxicity, permeability, and inflammation of me.pdf
#
# Processing item: 21664489.pdf
# Skipped non-PDF entry: 21664489.pdf
#
# Processing item: ZnO nanorod-induced apoptosis in human alveolar adenocarcinoma cells via p53, survivin and bax/bcl-2 pathways: Role of oxidative stress
# Found 1 children for item 'ZnO nanorod-induced apoptosis in human alveolar adenocarcinoma cells via p53, survivin and bax/bcl-2 pathways: Role of oxidative stress'
# PDF found: 21664489.pdf
# /home/pdf_pdfHa_3b/5I96BQWG.pdf already exists.
#
# Processing item: Effects of various physicochemical characteristics on the toxicities of ZnO and TiO2 nanoparticles toward human lung epithelial cells
# Found 1 children for item 'Effects of various physicochemical characteristics on the toxicities of ZnO and TiO2 nanoparticles toward human lung epithelial cells'
# PDF found: Hsiao 그리고 Huang - 2011 - Effects of various physicochemical characteristics.pdf
# /home/pdf_pdfHa_3b/U27TLPF7.pdf already exists.
#
# Processing item: 22303956
# Skipped non-PDF entry: 22303956
#
# Processing item: 22502734
# Skipped non-PDF entry: 22502734
#
# Processing item: 22931364
# Skipped non-PDF entry: 22931364
#
# Processing item: 23142470
# Skipped non-PDF entry: 23142470
#
# Processing item: 24078789
# Skipped non-PDF entry: 24078789
#
# Processing item: 24144420
# Skipped non-PDF entry: 24144420
#
# Processing item: 24983896
# Skipped non-PDF entry: 24983896
#
# Processing item: Microsomal glutathione transferase 1 protects against toxicity induced by silica nanoparticles but not by zinc oxide nanoparticles
# Found 1 children for item 'Microsomal glutathione transferase 1 protects against toxicity induced by silica nanoparticles but not by zinc oxide nanoparticles'
# PDF found: 22303956.pdf
# /home/pdf_pdfHa_3b/T43GGRMX.pdf already exists.
#
# Processing item: Use of metal oxide nanoparticle band gap to develop a predictive paradigm for oxidative stress and acute pulmonary inflammation
# Found 1 children for item 'Use of metal oxide nanoparticle band gap to develop a predictive paradigm for oxidative stress and acute pulmonary inflammation'
# PDF found: 22502734.pdf
# /home/pdf_pdfHa_3b/Q4GSNA3A.pdf already exists.
#
# Processing item: Mechanisms of toxicity of amorphous silica nanoparticles on human lung submucosal cells in vitro: protective effects of fisetin
# Found 1 children for item 'Mechanisms of toxicity of amorphous silica nanoparticles on human lung submucosal cells in vitro: protective effects of fisetin'
# PDF found: 22931364.pdf
# /home/pdf_pdfHa_3b/HEJLYCVK.pdf already exists.
#
# Processing item: Zinc oxide nanoparticles and monocytes: impact of size, charge and solubility on activation status
# Found 1 children for item 'Zinc oxide nanoparticles and monocytes: impact of size, charge and solubility on activation status'
# PDF found: 23142470.pdf
# /home/pdf_pdfHa_3b/5BHP8KES.pdf already exists.
#
# Processing item: Surface coatings of ZnO nanoparticles mitigate differentially a host of transcriptional, protein and signalling responses in primary human olfactory cells
# Found 1 children for item 'Surface coatings of ZnO nanoparticles mitigate differentially a host of transcriptional, protein and signalling responses in primary human olfactory cells'
# PDF found: 24144420.pdf
# /home/pdf_pdfHa_3b/ASCVGIJU.pdf already exists.
#
# Processing item: Effects of serum on cytotoxicity of nano- and micro-sized ZnO particles
# Found 1 children for item 'Effects of serum on cytotoxicity of nano- and micro-sized ZnO particles'
# PDF found: 24078789.pdf
# /home/pdf_pdfHa_3b/HAKJAMZY.pdf already exists.
#
# Processing item: Towards understanding mechanisms governing cytotoxicity of metal oxides nanoparticles: hints from nano-QSAR studies
# Found 1 children for item 'Towards understanding mechanisms governing cytotoxicity of metal oxides nanoparticles: hints from nano-QSAR studies'
# PDF found: 24983896.pdf
# /home/pdf_pdfHa_3b/FFWAKGE3.pdf already exists.

# %%
## Get PDF file list and IDs

pdf_files = []

for file_path in os.listdir(pdf_folder):
    if os.path.isfile(os.path.join(pdf_folder, file_path)):
        pdf_files.append(os.path.join(pdf_folder, file_path))

print(pdf_files)

# get pdf ids and store as pdf_ids
pdf_ids = []
for file_path in pdf_files:
    # get base name of file_pafth and remove .pdf
    base_name = os.path.basename(file_path)
    base_name = os.path.splitext(base_name)[0]
    pdf_ids.append(base_name)
print(pdf_ids)
# Out:
# ['/home/pdf_pdfHa_3b/6Z5K86RQ.pdf', '/home/pdf_pdfHa_3b/T43GGRMX.pdf', '/home/pdf_pdfHa_3b/HVPYYSLW.pdf', '/home/pdf_pdfHa_3b/5I96BQWG.pdf', '/home/pdf_pdfHa_3b/YNQITCKF.pdf', '/home/pdf_pdfHa_3b/FFWAKGE3.pdf', '/home/pdf_pdfHa_3b/HEJLYCVK.pdf', '/home/pdf_pdfHa_3b/Q4GSNA3A.pdf', '/home/pdf_pdfHa_3b/USNLP6MR.pdf', '/home/pdf_pdfHa_3b/5BHP8KES.pdf', '/home/pdf_pdfHa_3b/95ASP9SZ.pdf', '/home/pdf_pdfHa_3b/SKCFUKGT.pdf', '/home/pdf_pdfHa_3b/ASCVGIJU.pdf', '/home/pdf_pdfHa_3b/U27TLPF7.pdf', '/home/pdf_pdfHa_3b/HAKJAMZY.pdf', '/home/pdf_pdfHa_3b/EXQ8I7IY.pdf']
# ['6Z5K86RQ', 'T43GGRMX', 'HVPYYSLW', '5I96BQWG', 'YNQITCKF', 'FFWAKGE3', 'HEJLYCVK', 'Q4GSNA3A', 'USNLP6MR', '5BHP8KES', '95ASP9SZ', 'SKCFUKGT', 'ASCVGIJU', 'U27TLPF7', 'HAKJAMZY', 'EXQ8I7IY']

# %%
for key in pdf_ids:
    print (key)
# Out:
# 6Z5K86RQ
# T43GGRMX
# HVPYYSLW
# 5I96BQWG
# YNQITCKF
# FFWAKGE3
# HEJLYCVK
# Q4GSNA3A
# USNLP6MR
# 5BHP8KES
# 95ASP9SZ
# SKCFUKGT
# ASCVGIJU
# U27TLPF7
# HAKJAMZY
# EXQ8I7IY

# %% [markdown]
# # 5. ChatGPT with LangChain

# %%
from langchain.embeddings import OpenAIEmbeddings
OPENAI_API_KEY="open_ai_api_key"
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY, model="text-embedding-3-large")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:141: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
## Generate embeddings & save as files

# %%
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import PyPDFium2Loader
import os


error_files = []

def get_pdf_text(file_pafth):
    try:
        # get base name of file_pafth and remove .pdf
        base_name = os.path.basename(file_pafth)
        base_name = os.path.splitext(base_name)[0]
        print(base_name)

        em_path = "/home/workspace/embed/openai_em1118-2/" + base_name + "_openai"
        if not os.path.exists(em_path):
            # Load the PDF document
            load = PyPDFium2Loader(file_pafth)
            document = load.load()

            # Split text into chunks
            text_splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=50)
            texts = text_splitter.split_documents(document)

            # Embed the documents using FAISS
            db = FAISS.from_documents(texts, embeddings)

            # Save the FAISS index locally
            db.save_local(em_path)
            print(f"{em_path} is generated.")
        else:
            print(f"{em_path} already exists")
    except Exception as e:
        # Handle any exceptions and continue processing the next file
        print(f"Error processing {file_pafth}: {e}")
        # 오류가 발생한 파일명을 리스트에 추가
        error_files.append(file_pafth)

# Run get_pdf_text for all pdf_files
for file_path in pdf_files:
    get_pdf_text(file_path)
# Out:
# 6Z5K86RQ
# /usr/local/lib/python3.10/dist-packages/pypdfium2/_helpers/textpage.py:80: UserWarning: get_text_range() call with default params will be implicitly redirected to get_text_bounded()
#   warnings.warn("get_text_range() call with default params will be implicitly redirected to get_text_bounded()")
# /home/workspace/embed/openai_em1118-2/6Z5K86RQ_openai is generated.
# T43GGRMX
# /home/workspace/embed/openai_em1118-2/T43GGRMX_openai is generated.
# HVPYYSLW
# /home/workspace/embed/openai_em1118-2/HVPYYSLW_openai is generated.
# 5I96BQWG
# /home/workspace/embed/openai_em1118-2/5I96BQWG_openai is generated.
# YNQITCKF
# /home/workspace/embed/openai_em1118-2/YNQITCKF_openai is generated.
# FFWAKGE3
# /home/workspace/embed/openai_em1118-2/FFWAKGE3_openai is generated.
# HEJLYCVK
# /home/workspace/embed/openai_em1118-2/HEJLYCVK_openai is generated.
# Q4GSNA3A
# /home/workspace/embed/openai_em1118-2/Q4GSNA3A_openai is generated.
# USNLP6MR
# /home/workspace/embed/openai_em1118-2/USNLP6MR_openai is generated.
# 5BHP8KES
# /home/workspace/embed/openai_em1118-2/5BHP8KES_openai is generated.
# 95ASP9SZ
# /home/workspace/embed/openai_em1118-2/95ASP9SZ_openai is generated.
# SKCFUKGT
# /home/workspace/embed/openai_em1118-2/SKCFUKGT_openai is generated.
# ASCVGIJU
# /home/workspace/embed/openai_em1118-2/ASCVGIJU_openai is generated.
# U27TLPF7
# /home/workspace/embed/openai_em1118-2/U27TLPF7_openai is generated.
# HAKJAMZY
# /home/workspace/embed/openai_em1118-2/HAKJAMZY_openai is generated.
# EXQ8I7IY
# /home/workspace/embed/openai_em1118-2/EXQ8I7IY_openai is generated.

# %%
if error_files:
    print("The following files encountered errors:")
    for error_file in error_files:
        print(error_file)
else:
    print("No errors encountered.")
# Out:
# No errors encountered.

# %%
# 마지막 셀에 추가
embedding_end_time = time.time()
print(f"total notebook running time : {notebook_end_time - notebook_start_time}sec")
# Out:
# 노트북 전체 실행 시간: 92.12493801116943초

# %%
# Prepare LLM (ChatGPT)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import FAISS
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain_core.prompts import ChatPromptTemplate
from langchain.output_parsers import CommaSeparatedListOutputParser
from langchain.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough
##gpt-3.5-turbo-0125
##gpt-4o
chat = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model="gpt-4o")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:141: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
from langchain.callbacks import get_openai_callback

openai_cb = {}

def get_answer(doc_id, q, parser):
    db = FAISS.load_local("/home/workspace/embed/openai_em1118-2/" + doc_id + "_openai", embeddings,allow_dangerous_deserialization=True)
    prompt = PromptTemplate(
        template=template,
        input_variables=['context', 'question'],
        partial_variables = {"format_instructions": parser.get_format_instructions()},)
    retriever = db.as_retriever(search_kwargs={'k': 10})
    qa_llm = RetrievalQA.from_chain_type(llm = chat,
                                        chain_type = 'stuff',
                                        retriever = retriever,
                                        return_source_documents = True,
                                        chain_type_kwargs = {'prompt': prompt})
    with get_openai_callback() as cb:
        output = qa_llm({'query': q})
        now = datetime.datetime.now(timezone('Asia/Seoul'))
        now = now.strftime("%Y%m%d_%H%M%S")
        openai_cb[now] = cb
    return output

# %%
output_parser = CommaSeparatedListOutputParser()
mats_all_paper = {pdf_id: get_answer(pdf_id, q_mat, output_parser)['result'] for pdf_id in pdf_ids}
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:141: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   warn_deprecated(

# %%
mats_all_paper
# Out:
# {'6Z5K86RQ': 'SiO2 (SiO2)',
#  'T43GGRMX': 'TiO2 (TiO2), CeO2 (CeO2), ZnO (ZnO), SiO2 (SiO2)',
#  'HVPYYSLW': 'MTI5 (TiO2), P25 (TiO2), Nanofilament (TiO2), Hombitan (TiO2), Vive Nano Titania (TiO2)',
#  '5I96BQWG': 'ZnO nanorods (ZnO)',
#  'YNQITCKF': 'P60 (PLGA), P100 (PLGA), P200 (PLGA), T10 (TiO2), T20 (TiO2), T100 (TiO2)',
#  'FFWAKGE3': 'Fe2O3 (Fe2O3), In2O3 (In2O3), ZnO (ZnO), ZrO2 (ZrO2), Al2O3 (Al2O3)',
#  'HEJLYCVK': '10SiO2 (SiO2), 150SiO2 (SiO2), 500SiO2 (SiO2)',
#  'Q4GSNA3A': 'Al2O3 (Al2O3), CeO2 (CeO2), CoO (CoO), Cr2O3 (Cr2O3), Fe2O3 (Fe2O3), Gd2O3 (Gd2O3), HfO2 (HfO2), Ni2O3 (Ni2O3), SiO2 (SiO2), SnO2 (SnO2), Y2O3 (Y2O3), Yb2O3 (Yb2O3), ZrO2 (ZrO2), CuO (CuO), Co3O4 (Co3O4), Fe3O4 (Fe3O4), Sb2O3 (Sb2O3), TiO2 (TiO2), WO3 (WO3), ZnO (ZnO)',
#  'USNLP6MR': 'Si50 (SiO2), Si500 (SiO2)',
#  '5BHP8KES': 'Bulk ZnO (ZnO), Non Ionic ZnO (ZnO), Cationic ZnO (ZnO), Anionic ZnO (ZnO)',
#  '95ASP9SZ': 'P25 (TiO2), TiO2P25–300 (TiO2), TiO2P25–130 (TiO2), TiO2P25–70 (TiO2)',
#  'SKCFUKGT': 'ZnO (ZnO), Fe2O3 (Fe2O3), CuO (CuO)',
#  'ASCVGIJU': 'Z-COTE (ZnO), Nanosun (ZnO), Z-COTE HP1 (ZnO), Z-COTE MAX (ZnO)',
#  'U27TLPF7': 'ZnO-R8 (ZnO), ZnO-R19 (ZnO), ZnO-S6 (ZnO), ZnO-S25 (ZnO), ZnO-S38 (ZnO), TiO2-A (TiO2)',
#  'HAKJAMZY': 'nano-ZnO (ZnO), micro-ZnO (ZnO)',
#  'EXQ8I7IY': 'MFI-50 (SiO2), MFI-100 (SiO2)'}

# %% [markdown]
# # material data extracted

# %%
# OutputFixingPaser

from langchain.output_parsers import OutputFixingParser
fixing_parser = OutputFixingParser.from_llm(parser = output_parser, llm = chat)

mats_all_paper_fix = {}
for key, value in mats_all_paper.items():
    value_fix = fixing_parser.parse(value)
    mats_all_paper_fix[key] = value_fix

mats_all_paper_fix
# Out:
# {'6Z5K86RQ': ['SiO2 (SiO2)'],
#  'T43GGRMX': ['TiO2 (TiO2)', 'CeO2 (CeO2)', 'ZnO (ZnO)', 'SiO2 (SiO2)'],
#  'HVPYYSLW': ['MTI5 (TiO2)',
#   'P25 (TiO2)',
#   'Nanofilament (TiO2)',
#   'Hombitan (TiO2)',
#   'Vive Nano Titania (TiO2)'],
#  '5I96BQWG': ['ZnO nanorods (ZnO)'],
#  'YNQITCKF': ['P60 (PLGA)',
#   'P100 (PLGA)',
#   'P200 (PLGA)',
#   'T10 (TiO2)',
#   'T20 (TiO2)',
#   'T100 (TiO2)'],
#  'FFWAKGE3': ['Fe2O3 (Fe2O3)',
#   'In2O3 (In2O3)',
#   'ZnO (ZnO)',
#   'ZrO2 (ZrO2)',
#   'Al2O3 (Al2O3)'],
#  'HEJLYCVK': ['10SiO2 (SiO2)', '150SiO2 (SiO2)', '500SiO2 (SiO2)'],
#  'Q4GSNA3A': ['Al2O3 (Al2O3)',
#   'CeO2 (CeO2)',
#   'CoO (CoO)',
#   'Cr2O3 (Cr2O3)',
#   'Fe2O3 (Fe2O3)',
#   'Gd2O3 (Gd2O3)',
#   'HfO2 (HfO2)',
#   'Ni2O3 (Ni2O3)',
#   'SiO2 (SiO2)',
#   'SnO2 (SnO2)',
#   'Y2O3 (Y2O3)',
#   'Yb2O3 (Yb2O3)',
#   'ZrO2 (ZrO2)',
#   'CuO (CuO)',
#   'Co3O4 (Co3O4)',
#   'Fe3O4 (Fe3O4)',
#   'Sb2O3 (Sb2O3)',
#   'TiO2 (TiO2)',
#   'WO3 (WO3)',
#   'ZnO (ZnO)'],
#  'USNLP6MR': ['Si50 (SiO2)', 'Si500 (SiO2)'],
#  '5BHP8KES': ['Bulk ZnO (ZnO)',
#   'Non Ionic ZnO (ZnO)',
#   'Cationic ZnO (ZnO)',
#   'Anionic ZnO (ZnO)'],
#  '95ASP9SZ': ['P25 (TiO2)',
#   'TiO2P25–300 (TiO2)',
#   'TiO2P25–130 (TiO2)',
#   'TiO2P25–70 (TiO2)'],
#  'SKCFUKGT': ['ZnO (ZnO)', 'Fe2O3 (Fe2O3)', 'CuO (CuO)'],
#  'ASCVGIJU': ['Z-COTE (ZnO)',
#   'Nanosun (ZnO)',
#   'Z-COTE HP1 (ZnO)',
#   'Z-COTE MAX (ZnO)'],
#  'U27TLPF7': ['ZnO-R8 (ZnO)',
#   'ZnO-R19 (ZnO)',
#   'ZnO-S6 (ZnO)',
#   'ZnO-S25 (ZnO)',
#   'ZnO-S38 (ZnO)',
#   'TiO2-A (TiO2)'],
#  'HAKJAMZY': ['nano-ZnO (ZnO)', 'micro-ZnO (ZnO)'],
#  'EXQ8I7IY': ['MFI-50 (SiO2)', 'MFI-100 (SiO2)']}

# %%
# Pchem info. extraction

# %%
from dataclasses import dataclass

@dataclass
class gpt_responses:
    pdf_id: str
    mat_name: str
    pchem_product_info: str
    pchem_mat_synthesis: str
    pchem_core_size: str
    pchem_hydrodynamic_size: str
    pchem_surface_charge: str
    pchem_surface_area: str

# %%
import json
import textwrap
import langchain_core.output_parsers


def get_sub_answers(mat, q, key, data_class):
    schema = data_class.schema()
    field_names = list(schema['properties'].keys())
    field_names.insert(0, 'key')
    #print(field_names)

    output_parser = PydanticOutputParser(pydantic_object=data_class)
    ans = get_answer(key, q, output_parser)

    fixing_parser = OutputFixingParser.from_llm(parser = output_parser, llm = chat)

    text = ans['result']
    py = fixing_parser.parse(text)
    py_dict = py.to_dict()

    #print(py_dict)

    pchem_df = pd.DataFrame.from_records(py_dict, index = ["0"])
    pchem_df.insert(0, 'key', key)
    #pchem_df.insert(0, 'ref', pdf_dict[key])
    print(pchem_df)

    return(pchem_df)

#i = "TiO2 P25–70 nano-TiO2"
#q = "please pull out material information of " + i + " in the document."
#tmp = get_sub_answers(i, q, "95ASP9SZ", pchem_product_info)

# %%
all_pchem_dfs = []
all_gpt_responses = []
error_files = []

for key, value in mats_all_paper_fix.items():
    try:
        # make for loop to print each value
        for i in value:
            print(key + ": " + i)

            q = "please pull out material information of " + i + " in the document."
            pchem_df = get_sub_answers(i, q, key, pchem_product_info)

            q = "please pull out material synthesis information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_mat_synthesis)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')

            q = "please pull out core size information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_core_size)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')

            q = "please pull out hydrodynamic size information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_hydrodynamic_size)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')

            q = "please pull out surface charge information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_surface_charge)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')

            q = "please pull out surface area information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_surface_area)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')
            pchem_df.insert(0, 'ref', pdf_dict[key])

            # Append pchem_df to the list
            all_pchem_dfs.append(pchem_df)

    except Exception as e:
        # 오류가 발생한 파일을 기록하고, 다음 파일로 넘어감
        print(f"Error processing {key}: {e}")
        error_files.append(key)

# Combine all pchem_df DataFrames into a single DataFrame
all_pchem_df = pd.concat(all_pchem_dfs, ignore_index=True)
all_pchem_df['ref'] = all_pchem_df['key'].map(lambda x: pdf_dict[x] if x in pdf_dict else None)
# Out:
# 6Z5K86RQ: SiO2 (SiO2)
#         key     mat_name
# 0  6Z5K86RQ  SiO2 (SiO2)
#         key           mat_synthesis
# 0  6Z5K86RQ  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  6Z5K86RQ     33.5±7.73                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key       mat_hydrodynamic_size  \
# 0  6Z5K86RQ  120±23.8 (Solvent: medium)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  6Z5K86RQ               None                                  None
#
#   mat_surface_charge_source
# 0                      None
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  6Z5K86RQ      576.23±7.87                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# T43GGRMX: TiO2 (TiO2)
#         key     mat_name
# 0  T43GGRMX  TiO2 (TiO2)
#         key                          mat_synthesis
# 0  T43GGRMX  Commercially available (Aeroxide P25)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  T43GGRMX       29.2±10                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key                              mat_hydrodynamic_size  \
# 0  T43GGRMX  1.38±0.03 (Solvent: culture media); 2.3±0.2 (S...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key                      mat_surface_charge  \
# 0  T43GGRMX  1.38±0.03 (pH: 7.4); 2.3±0.2 (pH: 7.4)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  T43GGRMX             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# T43GGRMX: CeO2 (CeO2)
#         key     mat_name
# 0  T43GGRMX  CeO2 (CeO2)
#         key mat_synthesis
# 0  T43GGRMX          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  T43GGRMX        23.4±4                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key                              mat_hydrodynamic_size  \
# 0  T43GGRMX  40±3 (Solvent: medium); 1.4±0.02 (Solvent: med...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key      mat_surface_charge mat_surface_charge_measurement_method  \
# 0  T43GGRMX  40±3 (Solvent: medium)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  T43GGRMX             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# T43GGRMX: ZnO (ZnO)
#         key   mat_name
# 0  T43GGRMX  ZnO (ZnO)
#         key mat_synthesis
# 0  T43GGRMX          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  T43GGRMX        15.5±4                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key   mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  T43GGRMX  28±4 (Solvent: medium)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  T43GGRMX               28±4                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  T43GGRMX             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# T43GGRMX: SiO2 (SiO2)
#         key     mat_name
# 0  T43GGRMX  SiO2 (SiO2)
#         key           mat_synthesis
# 0  T43GGRMX  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  T43GGRMX        12.0±2                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key                              mat_hydrodynamic_size  \
# 0  T43GGRMX  30 (Solvent: culture media); 34.9 (Solvent: wa...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  T43GGRMX       30 (pH: 7.4)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  T43GGRMX             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# HVPYYSLW: MTI5 (TiO2)
#         key     mat_name
# 0  HVPYYSLW  MTI5 (TiO2)
#         key           mat_synthesis
# 0  HVPYYSLW  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HVPYYSLW         1-200                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key        mat_hydrodynamic_size  \
# 0  HVPYYSLW  460 (Solvent: media; pH: 8)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  HVPYYSLW        -12 (pH: 8)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HVPYYSLW            280.9                                 BET
#
#   mat_surface_area_source
# 0           Not specified
# HVPYYSLW: P25 (TiO2)
#         key    mat_name
# 0  HVPYYSLW  P25 (TiO2)
#         key           mat_synthesis
# 0  HVPYYSLW  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HVPYYSLW         1-200                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key               mat_hydrodynamic_size  \
# 0  HVPYYSLW  400 (Concentration: not specified)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  HVPYYSLW        -12 (pH: 8)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HVPYYSLW             48.9                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# HVPYYSLW: Nanofilament (TiO2)
#         key             mat_name
# 0  HVPYYSLW  Nanofilament (TiO2)
#         key           mat_synthesis
# 0  HVPYYSLW  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HVPYYSLW         10x40                             None
#
#   mat_core_size_source
# 0         Manufacturer
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  HVPYYSLW                   420                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  HVPYYSLW        -12 (pH: 8)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HVPYYSLW            107.4                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# HVPYYSLW: Hombitan (TiO2)
#         key         mat_name
# 0  HVPYYSLW  Hombitan (TiO2)
#         key                                      mat_synthesis
# 0  HVPYYSLW  Commercially available (Hombitan LW-S provided...
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HVPYYSLW         1-200                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key                              mat_hydrodynamic_size  \
# 0  HVPYYSLW  365 (Concentration: 10 mg/L); 12.3±1.1 (Concen...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  HVPYYSLW        -13 (pH: 8)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HVPYYSLW              9.8                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# HVPYYSLW: Vive Nano Titania (TiO2)
#         key                  mat_name
# 0  HVPYYSLW  Vive Nano Titania (TiO2)
#         key           mat_synthesis
# 0  HVPYYSLW  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HVPYYSLW         1-200                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  HVPYYSLW                   600                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  HVPYYSLW        -19 (pH: 8)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HVPYYSLW             None                                 BET
#
#   mat_surface_area_source
# 0           Not specified
# 5I96BQWG: ZnO nanorods (ZnO)
#         key            mat_name
# 0  5I96BQWG  ZnO nanorods (ZnO)
#         key mat_synthesis
# 0  5I96BQWG   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  5I96BQWG            52                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key              mat_hydrodynamic_size  \
# 0  5I96BQWG  97 (Solvent: cell culture medium)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  5I96BQWG               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  5I96BQWG             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# YNQITCKF: P60 (PLGA)
#         key    mat_name
# 0  YNQITCKF  P60 (PLGA)
#         key mat_synthesis
# 0  YNQITCKF   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  YNQITCKF            61                              SEM
#
#   mat_core_size_source
# 0           Experiment
#         key                        mat_hydrodynamic_size  \
# 0  YNQITCKF  192 (Solvent: medium); 101 (Solvent: water)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                     None                   Experiment
#         key                               mat_surface_charge  \
# 0  YNQITCKF  -17.0 (Solvent: water); -17.0 (Solvent: medium)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  YNQITCKF             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# YNQITCKF: P100 (PLGA)
#         key     mat_name
# 0  YNQITCKF  P100 (PLGA)
#         key mat_synthesis
# 0  YNQITCKF   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  YNQITCKF            94                              SEM
#
#   mat_core_size_source
# 0           Experiment
#         key  mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  YNQITCKF  120 (Solvent: medium)                                     None
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  YNQITCKF               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  YNQITCKF             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# YNQITCKF: P200 (PLGA)
#         key     mat_name
# 0  YNQITCKF  P200 (PLGA)
#         key mat_synthesis
# 0  YNQITCKF   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  YNQITCKF           205                              SEM
#
#   mat_core_size_source
# 0           Experiment
#         key  mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  YNQITCKF  196 (Solvent: medium)                                     None
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  YNQITCKF               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  YNQITCKF             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# YNQITCKF: T10 (TiO2)
#         key    mat_name
# 0  YNQITCKF  T10 (TiO2)
#         key           mat_synthesis
# 0  YNQITCKF  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  YNQITCKF            10                              TEM
#
#   mat_core_size_source
# 0         Manufacturer
#         key                        mat_hydrodynamic_size  \
# 0  YNQITCKF  262 (Solvent: medium); 669 (Solvent: water)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key      mat_surface_charge mat_surface_charge_measurement_method  \
# 0  YNQITCKF  32.3 (Solvent: medium)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  YNQITCKF            166.0                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# YNQITCKF: T20 (TiO2)
#         key    mat_name
# 0  YNQITCKF  T20 (TiO2)
#         key           mat_synthesis
# 0  YNQITCKF  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  YNQITCKF            20                              TEM
#
#   mat_core_size_source
# 0         Manufacturer
#         key  mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  YNQITCKF  338 (Solvent: medium)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key                            mat_surface_charge  \
# 0  YNQITCKF  32.3 (Solvent: water); 19.1 (Solvent: CDMEM)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  YNQITCKF             50.4                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# YNQITCKF: T100 (TiO2)
#         key     mat_name
# 0  YNQITCKF  T100 (TiO2)
#         key           mat_synthesis
# 0  YNQITCKF  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  YNQITCKF           100                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key                       mat_hydrodynamic_size  \
# 0  YNQITCKF  349 (Solvent: water); 444 (Solvent: CDMEM)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  YNQITCKF               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  YNQITCKF            166.0                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# FFWAKGE3: Fe2O3 (Fe2O3)
#         key       mat_name
# 0  FFWAKGE3  Fe2O3 (Fe2O3)
#         key mat_synthesis
# 0  FFWAKGE3          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  FFWAKGE3          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  FFWAKGE3                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  FFWAKGE3          -1.18E+05                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  FFWAKGE3              150                                None
#
#   mat_surface_area_source
# 0           Not specified
# FFWAKGE3: In2O3 (In2O3)
#         key       mat_name
# 0  FFWAKGE3  In2O3 (In2O3)
#         key mat_synthesis
# 0  FFWAKGE3          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  FFWAKGE3          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  FFWAKGE3                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key    mat_surface_charge mat_surface_charge_measurement_method  \
# 0  FFWAKGE3  -10.62 (pH: Unknown)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  FFWAKGE3             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# FFWAKGE3: ZnO (ZnO)
#         key   mat_name
# 0  FFWAKGE3  ZnO (ZnO)
#         key mat_synthesis
# 0  FFWAKGE3          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  FFWAKGE3          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  FFWAKGE3                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  FFWAKGE3          -3.04E+05                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  FFWAKGE3             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# FFWAKGE3: ZrO2 (ZrO2)
#         key     mat_name
# 0  FFWAKGE3  ZrO2 (ZrO2)
#         key mat_synthesis
# 0  FFWAKGE3          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  FFWAKGE3          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  FFWAKGE3                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key             mat_surface_charge  \
# 0  FFWAKGE3  -10.92 (Solvent: unspecified)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  FFWAKGE3             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# FFWAKGE3: Al2O3 (Al2O3)
#         key       mat_name
# 0  FFWAKGE3  Al2O3 (Al2O3)
#         key mat_synthesis
# 0  FFWAKGE3          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  FFWAKGE3          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  FFWAKGE3                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  FFWAKGE3               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  FFWAKGE3           307.16                                None
#
#   mat_surface_area_source
# 0           Not specified
# HEJLYCVK: 10SiO2 (SiO2)
#         key       mat_name
# 0  HEJLYCVK  10SiO2 (SiO2)
#         key           mat_synthesis
# 0  HEJLYCVK  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HEJLYCVK    10.50±0.19                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key           mat_hydrodynamic_size  \
# 0  HEJLYCVK  12.5±0.32 (Solvent: SF medium)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key                                 mat_surface_charge  \
# 0  HEJLYCVK  -25±0.45 (Solvent: SF medium); -43.4 (Solvent:...
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HEJLYCVK             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# HEJLYCVK: 150SiO2 (SiO2)
#         key        mat_name
# 0  HEJLYCVK  150SiO2 (SiO2)
#         key           mat_synthesis
# 0  HEJLYCVK  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HEJLYCVK   148.20±2.19                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key            mat_hydrodynamic_size  \
# 0  HEJLYCVK  154.6±0.95 (Solvent: SF medium)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key            mat_surface_charge  \
# 0  HEJLYCVK  -27.3±2.55 (Solvent: medium)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HEJLYCVK             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# HEJLYCVK: 500SiO2 (SiO2)
#         key        mat_name
# 0  HEJLYCVK  500SiO2 (SiO2)
#         key           mat_synthesis
# 0  HEJLYCVK  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HEJLYCVK   495.90±5.87                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key       mat_hydrodynamic_size  \
# 0  HEJLYCVK  492±5.68 (Solvent: medium)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key                                 mat_surface_charge  \
# 0  HEJLYCVK  -29.6±0.78 (Solvent: SF medium); >-30 (Solvent...
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HEJLYCVK             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Al2O3 (Al2O3)
#         key       mat_name
# 0  Q4GSNA3A  Al2O3 (Al2O3)
#         key mat_synthesis
# 0  Q4GSNA3A          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A     5.67±8.30                             None
#
#   mat_core_size_source
# 0         Manufacturer
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  260.4±16.9 (Solvent: BEGM); 230.5±6.6 (Solvent...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                     None                Not specified
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0                    None
# Q4GSNA3A: CeO2 (CeO2)
#         key     mat_name
# 0  Q4GSNA3A  CeO2 (CeO2)
#         key                            mat_synthesis
# 0  Q4GSNA3A  Commercially available (CeO2 NPs, 8 nm)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  261.6±7.3 (Solvent: BEGM); 248.4±2.2 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: CoO (CoO)
#         key   mat_name
# 0  Q4GSNA3A  CoO (CoO)
#         key                                      mat_synthesis
# 0  Q4GSNA3A  Commercially available (with cat# or product #...
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  208.3±5.4 (Solvent: BEGM); 191.6±7.1 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key      mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A  -4.42 (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0                    None
# Q4GSNA3A: Cr2O3 (Cr2O3)
#         key       mat_name
# 0  Q4GSNA3A  Cr2O3 (Cr2O3)
#         key                    mat_synthesis
# 0  Q4GSNA3A  Commercially available (US3060)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A      193±90.0                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  256.4±5.4 (Solvent: BEGM); 316.9±5.6 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key      mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A  -4.44 (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Fe2O3 (Fe2O3)
#         key       mat_name
# 0  Q4GSNA3A  Fe2O3 (Fe2O3)
#         key                    mat_synthesis
# 0  Q4GSNA3A  Commercially available (US3200)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  144.7±2.7 (Solvent: BEGM); 206.3±6.8 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0                      None
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Gd2O3 (Gd2O3)
#         key       mat_name
# 0  Q4GSNA3A  Gd2O3 (Gd2O3)
#         key                    mat_synthesis
# 0  Q4GSNA3A  Commercially available (2681RE)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  195.7±4.3 (Solvent: BEGM); 227.4±4.6 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A      -2.83 (pH: 8)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             5.50                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: HfO2 (HfO2)
#         key     mat_name
# 0  Q4GSNA3A  HfO2 (HfO2)
#         key                    mat_synthesis
# 0  Q4GSNA3A  Commercially available (US3245)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  291.8±11.2 (Solvent: BEGM); 307.7±4.3 (Solvent...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0                      None
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A         28.4±7.3                       Not specified
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Ni2O3 (Ni2O3)
#         key       mat_name
# 0  Q4GSNA3A  Ni2O3 (Ni2O3)
#         key                              mat_synthesis
# 0  Q4GSNA3A  Commercially available (with cat# 5420SC)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A    140.6±52.5                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  311.4±7.1 (Solvent: BEGM); 339.5±9.9 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: SiO2 (SiO2)
#         key     mat_name
# 0  Q4GSNA3A  SiO2 (SiO2)
#         key                       mat_synthesis
# 0  Q4GSNA3A  Commercially available (US 4850MR)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key  mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  Q4GSNA3A  9.10 (Solvent: water)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A         13.5±4.2                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: SnO2 (SnO2)
#         key     mat_name
# 0  Q4GSNA3A  SnO2 (SnO2)
#         key                    mat_synthesis
# 0  Q4GSNA3A  Commercially available (US3460)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  203.7±4.7 (Solvent: water); 242.5±5.0 (Solvent...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key              mat_surface_charge  \
# 0  Q4GSNA3A  -4.01 (Solvent: not specified)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Y2O3 (Y2O3)
#         key     mat_name
# 0  Q4GSNA3A  Y2O3 (Y2O3)
#         key                               mat_synthesis
# 0  Q4GSNA3A  Commercially available (Y2O3 NPs, 8–10 nm)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          8-10                             None
#
#   mat_core_size_source
# 0         Manufacturer
#         key                       mat_hydrodynamic_size  \
# 0  Q4GSNA3A  312.2±15.4 (Solvent: tissue culture media)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key              mat_surface_charge  \
# 0  Q4GSNA3A  -2.35 (Solvent: not specified)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             5.41                       Not specified
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Yb2O3 (Yb2O3)
#         key       mat_name
# 0  Q4GSNA3A  Yb2O3 (Yb2O3)
#         key                           mat_synthesis
# 0  Q4GSNA3A  Commercially available (MKN-Yb2O3-090)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  230.7±1.8 (Solvent: water); 296.1±5.7 (Solvent...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A   -2.83 (pH: 5.10)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A        61.7±11.3                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: ZrO2 (ZrO2)
#         key     mat_name
# 0  Q4GSNA3A  ZrO2 (ZrO2)
#         key                    mat_synthesis
# 0  Q4GSNA3A  Commercially available (US3600)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  306.5±10.3 (Solvent: BEGM); 314.3±9.9 (Solvent...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A        5.62±5.04                       Not specified
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: CuO (CuO)
#         key   mat_name
# 0  Q4GSNA3A  CuO (CuO)
#         key mat_synthesis
# 0  Q4GSNA3A   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  305.3±5.6 (Solvent: BEGM); 313.8±4.9 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A        263.3±4.5                       Not specified
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Co3O4 (Co3O4)
#         key       mat_name
# 0  Q4GSNA3A  Co3O4 (Co3O4)
#         key mat_synthesis
# 0  Q4GSNA3A   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A        10-100                              TEM
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  222.7±4.4 (Solvent: BEGM); 230.3±4.5 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A              -4.59                        Zeta potential
#
#   mat_surface_charge_source
# 0                      None
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Fe3O4 (Fe3O4)
#         key       mat_name
# 0  Q4GSNA3A  Fe3O4 (Fe3O4)
#         key mat_synthesis
# 0  Q4GSNA3A   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A      12.0±3.2                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  198.4±4.1 (Solvent: BEGM); 256.6±9.3 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key                mat_surface_charge  \
# 0  Q4GSNA3A  -5.00 (pH: 7.2); -6.85 (pH: 7.5)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: Sb2O3 (Sb2O3)
#         key       mat_name
# 0  Q4GSNA3A  Sb2O3 (Sb2O3)
#         key mat_synthesis
# 0  Q4GSNA3A          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  274.9±19.3 (Solvent: water); 195.5±3.1 (Solven...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: TiO2 (TiO2)
#         key     mat_name
# 0  Q4GSNA3A  TiO2 (TiO2)
#         key mat_synthesis
# 0  Q4GSNA3A   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  3.33±6.4 (Solvent: BEGM); 4.16±7.49 (Solvent: ...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A         12.6±4.3                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: WO3 (WO3)
#         key   mat_name
# 0  Q4GSNA3A  WO3 (WO3)
#         key mat_synthesis
# 0  Q4GSNA3A   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A      16.6±4.3                             None
#
#   mat_core_size_source
# 0           Experiment
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  196.1±2.5 (Solvent: BEGM); 198.5±2.2 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A    -5.53 (pH: 7.4)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# Q4GSNA3A: ZnO (ZnO)
#         key   mat_name
# 0  Q4GSNA3A  ZnO (ZnO)
#         key mat_synthesis
# 0  Q4GSNA3A   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  Q4GSNA3A          None                             None
#
#   mat_core_size_source
# 0        Not specified
#         key                              mat_hydrodynamic_size  \
# 0  Q4GSNA3A  114.7±10.5 (Solvent: BEGM); 69.4±0.4 (Solvent:...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  Q4GSNA3A                9.6                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  Q4GSNA3A             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# USNLP6MR: Si50 (SiO2)
#         key     mat_name
# 0  USNLP6MR  Si50 (SiO2)
#         key                                     mat_synthesis
# 0  USNLP6MR  Commercially available (with cat# GK 1890843-02)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  USNLP6MR      27.5±4.7                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key                              mat_hydrodynamic_size  \
# 0  USNLP6MR  75.1 (Solvent: water); None (Solvent: culture ...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key      mat_surface_charge mat_surface_charge_measurement_method  \
# 0  USNLP6MR  -29.5 (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  USNLP6MR               65                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# USNLP6MR: Si500 (SiO2)
#         key      mat_name
# 0  USNLP6MR  Si500 (SiO2)
#         key                         mat_synthesis
# 0  USNLP6MR  Commercially available (GK 0850343T)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  USNLP6MR        369±20                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  USNLP6MR  546 (Solvent: water)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key      mat_surface_charge mat_surface_charge_measurement_method  \
# 0  USNLP6MR  -38.7 (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  USNLP6MR                9                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# 5BHP8KES: Bulk ZnO (ZnO)
#         key        mat_name
# 0  5BHP8KES  Bulk ZnO (ZnO)
#         key           mat_synthesis
# 0  5BHP8KES  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  5BHP8KES            44                              SEM
#
#   mat_core_size_source
# 0        Not specified
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  5BHP8KES                  None                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  5BHP8KES               None                                  None
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  5BHP8KES             None                                None
#
#   mat_surface_area_source
# 0           Not specified
# 5BHP8KES: Non Ionic ZnO (ZnO)
#         key             mat_name
# 0  5BHP8KES  Non Ionic ZnO (ZnO)
#         key                                      mat_synthesis
# 0  5BHP8KES  Commercially available (with cat# or product #...
#         key mat_core_size mat_core_size_measurement_method  \
# 0  5BHP8KES            70                             None
#
#   mat_core_size_source
# 0         Manufacturer
#         key                              mat_hydrodynamic_size  \
# ...
# 0  SKCFUKGT     32.7 (pH: 7.4)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  SKCFUKGT             21.3                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# SKCFUKGT: Fe2O3 (Fe2O3)
#         key       mat_name
# 0  SKCFUKGT  Fe2O3 (Fe2O3)
#         key                             mat_synthesis
# 0  SKCFUKGT  Commercially available (Cat. no. 544884)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  SKCFUKGT          42.5                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  SKCFUKGT                   957                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  SKCFUKGT     -8.2 (pH: 7.4)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  SKCFUKGT             82.8                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# SKCFUKGT: CuO (CuO)
#         key   mat_name
# 0  SKCFUKGT  CuO (CuO)
#         key mat_synthesis
# 0  SKCFUKGT          None
#         key mat_core_size mat_core_size_measurement_method  \
# 0  SKCFUKGT          46.3                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  SKCFUKGT                   239                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  SKCFUKGT               42.8                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  SKCFUKGT             24.1                                 BET
#
#   mat_surface_area_source
# 0           Not specified
# ASCVGIJU: Z-COTE (ZnO)
#         key                                           mat_name
# 0  ASCVGIJU  Z-COTE (ZnO), Nanosun (ZnO), Z-COTE HP1 (ZnO),...
#         key                                mat_synthesis
# 0  ASCVGIJU  Commercially available (with cat# EHDA3001)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  ASCVGIJU         44-73                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  ASCVGIJU                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key         mat_surface_charge mat_surface_charge_measurement_method  \
# 0  ASCVGIJU  Positive (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  ASCVGIJU             13±2                       Not specified
#
#   mat_surface_area_source
# 0           Not specified
# ASCVGIJU: Nanosun (ZnO)
#         key       mat_name
# 0  ASCVGIJU  Nanosun (ZnO)
#         key                            mat_synthesis
# 0  ASCVGIJU  Commercially available (with cat# 4051)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  ASCVGIJU            25                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  ASCVGIJU                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key         mat_surface_charge mat_surface_charge_measurement_method  \
# 0  ASCVGIJU  Positive (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  ASCVGIJU             30±3                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# ASCVGIJU: Z-COTE HP1 (ZnO)
#         key   mat_name
# 0  ASCVGIJU  HP1 (ZnO)
#         key                             mat_synthesis
# 0  ASCVGIJU  Commercially available (batch# CNHE0602)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  ASCVGIJU         28-96                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  ASCVGIJU                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key mat_surface_charge mat_surface_charge_measurement_method  \
# 0  ASCVGIJU               None                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  ASCVGIJU         14.9±0.5                       Not specified
#
#   mat_surface_area_source
# 0              Experiment
# ASCVGIJU: Z-COTE MAX (ZnO)
#         key          mat_name
# 0  ASCVGIJU  Z-COTE MAX (ZnO)
#         key                           mat_synthesis
# 0  ASCVGIJU  Commercially available (cat# FCHE1301)
#         key mat_core_size mat_core_size_measurement_method  \
# 0  ASCVGIJU            36                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  ASCVGIJU                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key  mat_surface_charge mat_surface_charge_measurement_method  \
# 0  ASCVGIJU  - (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  ASCVGIJU             12±1                                None
#
#   mat_surface_area_source
# 0           Not specified
# U27TLPF7: ZnO-R8 (ZnO)
#         key      mat_name
# 0  U27TLPF7  ZnO-R8 (ZnO)
#         key mat_synthesis
# 0  U27TLPF7   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  U27TLPF7          5-16                              XRD
#
#   mat_core_size_source
# 0           Experiment
#         key  mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  U27TLPF7  914 (Solvent: medium)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key                             mat_surface_charge  \
# 0  U27TLPF7  29.8 (Solvent: water); None (Solvent: medium)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  U27TLPF7               88                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# U27TLPF7: ZnO-R19 (ZnO)
#         key       mat_name
# 0  U27TLPF7  ZnO-R19 (ZnO)
#         key mat_synthesis
# 0  U27TLPF7   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  U27TLPF7         16-48                              XRD
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  U27TLPF7  1093 (Solvent: DMEM)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key    mat_surface_charge mat_surface_charge_measurement_method  \
# 0  U27TLPF7  21.6 (Solvent: DMEM)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  U27TLPF7               37                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# U27TLPF7: ZnO-S6 (ZnO)
#         key      mat_name
# 0  U27TLPF7  ZnO-S6 (ZnO)
#         key mat_synthesis
# 0  U27TLPF7   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  U27TLPF7          5-10                              TEM
#
#   mat_core_size_source
# 0           Experiment
#         key  mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  U27TLPF7  795 (Solvent: medium)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key    mat_surface_charge mat_surface_charge_measurement_method  \
# 0  U27TLPF7  27.4 (Solvent: DMEM)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  U27TLPF7               90                       Not specified
#
#   mat_surface_area_source
# 0              Experiment
# U27TLPF7: ZnO-S25 (ZnO)
#         key       mat_name
# 0  U27TLPF7  ZnO-S25 (ZnO)
#         key mat_synthesis
# 0  U27TLPF7   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  U27TLPF7         36-68                             None
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  U27TLPF7   640 (Solvent: DMEM)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key     mat_surface_charge mat_surface_charge_measurement_method  \
# 0  U27TLPF7  29.4 (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  U27TLPF7               15                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# U27TLPF7: ZnO-S38 (ZnO)
#         key       mat_name
# 0  U27TLPF7  ZnO-S38 (ZnO)
#         key mat_synthesis
# 0  U27TLPF7   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  U27TLPF7        50-122                             None
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  U27TLPF7   687 (Solvent: DMEM)                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key     mat_surface_charge mat_surface_charge_measurement_method  \
# 0  U27TLPF7  31.3 (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  U27TLPF7                7                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# U27TLPF7: TiO2-A (TiO2)
#         key       mat_name
# 0  U27TLPF7  TiO2-A (TiO2)
#         key mat_synthesis
# 0  U27TLPF7   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  U27TLPF7        90-160                             None
#
#   mat_core_size_source
# 0           Experiment
#         key                       mat_hydrodynamic_size  \
# 0  U27TLPF7  661 (Solvent: water); 1054 (Solvent: DMEM)
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key      mat_surface_charge mat_surface_charge_measurement_method  \
# 0  U27TLPF7  -40.8 (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0             Not specified
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  U27TLPF7               38                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# HAKJAMZY: nano-ZnO (ZnO)
#         key        mat_name
# 0  HAKJAMZY  Nano-ZnO (ZnO)
#         key           mat_synthesis
# 0  HAKJAMZY  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HAKJAMZY         50-70                              TEM
#
#   mat_core_size_source
# 0         Manufacturer
#         key                              mat_hydrodynamic_size  \
# 0  HAKJAMZY  936 (Solvent: serum-free DMEM); 279 (Solvent: ...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key                                 mat_surface_charge  \
# 0  HAKJAMZY  -2.4 (Solvent: DMEM); -7.5 (Solvent: DMEM/5% F...
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HAKJAMZY             7.34                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# HAKJAMZY: micro-ZnO (ZnO)
#         key         mat_name
# 0  HAKJAMZY  Micro-ZnO (ZnO)
#         key           mat_synthesis
# 0  HAKJAMZY  Commercially available
#         key mat_core_size mat_core_size_measurement_method  \
# 0  HAKJAMZY          None                              TEM
#
#   mat_core_size_source
# 0         Manufacturer
#         key                              mat_hydrodynamic_size  \
# 0  HAKJAMZY  530 (Solvent: DMEM); 1107 (Solvent: DMEM, Seru...
#
#   mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source
# 0                                      DLS                   Experiment
#         key                                 mat_surface_charge  \
# 0  HAKJAMZY  -4.0 (Solvent: DMEM); -8.2 (Solvent: DMEM/5% F...
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  HAKJAMZY             1.81                                 BET
#
#   mat_surface_area_source
# 0              Experiment
# EXQ8I7IY: MFI-50 (SiO2)
#         key       mat_name
# 0  EXQ8I7IY  MFI-50 (SiO2)
#         key mat_synthesis
# 0  EXQ8I7IY   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  EXQ8I7IY            50                              SEM
#
#   mat_core_size_source
# 0           Experiment
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  EXQ8I7IY                  None                                     None
#
#   mat_hydrodynamic_size_source
# 0                Not specified
#         key          mat_surface_charge mat_surface_charge_measurement_method  \
# 0  EXQ8I7IY  -13.2±0.7 (Solvent: water)                        Zeta potential
#
#   mat_surface_charge_source
# 0                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  EXQ8I7IY        108.3±0.4                                None
#
#   mat_surface_area_source
# 0           Not specified
# EXQ8I7IY: MFI-100 (SiO2)
#         key        mat_name
# 0  EXQ8I7IY  MFI-100 (SiO2)
#         key mat_synthesis
# 0  EXQ8I7IY   Synthesized
#         key mat_core_size mat_core_size_measurement_method  \
# 0  EXQ8I7IY           100                              SEM
#
#   mat_core_size_source
# 0        Not specified
#         key mat_hydrodynamic_size mat_hydrodynamic_size_measurement_method  \
# 0  EXQ8I7IY                  None                                      DLS
#
#   mat_hydrodynamic_size_source
# 0                   Experiment
#         key           mat_surface_charge  \
# 0  EXQ8I7IY  -12.6±0.8 (Time: immediate)
#
#   mat_surface_charge_measurement_method mat_surface_charge_source
# 0                        Zeta potential                Experiment
#         key mat_surface_area mat_surface_area_measurement_method  \
# 0  EXQ8I7IY         48.1±0.2                                None
#
#   mat_surface_area_source
# 0           Not specified

# %%
# 오류가 발생한 파일 출력
if error_files:
    print("The following files encountered errors:")
    for error_file in error_files:
        print(error_file)
else:
    print("No errors encountered.")
# Out:
# No errors encountered.

# %% [markdown]
# # Pchem data extraction result

# %%
all_pchem_df
# Out:
#                                                   ref       key  \
# 0   Michael Berg 등 - 2013 - Comparative cytologica...  6Z5K86RQ
# 1                                            22303956  T43GGRMX
# 2                                            22303956  T43GGRMX
# 3                                            22303956  T43GGRMX
# 4                                            22303956  T43GGRMX
# ..                                                ...       ...
# 67  Hsiao 그리고 Huang - 2011 - Effects of various ph...  U27TLPF7
# 68                                           24078789  HAKJAMZY
# 69                                           24078789  HAKJAMZY
# 70                                           23103338  EXQ8I7IY
# 71                                           23103338  EXQ8I7IY
#
#            mat_name                          mat_synthesis mat_core_size  \
# 0       SiO2 (SiO2)                 Commercially available     33.5±7.73
# 1       TiO2 (TiO2)  Commercially available (Aeroxide P25)       29.2±10
# 2       CeO2 (CeO2)                                   None        23.4±4
# 3         ZnO (ZnO)                                   None        15.5±4
# 4       SiO2 (SiO2)                 Commercially available        12.0±2
# ..              ...                                    ...           ...
# 67    TiO2-A (TiO2)                            Synthesized        90-160
# 68   Nano-ZnO (ZnO)                 Commercially available         50-70
# 69  Micro-ZnO (ZnO)                 Commercially available          None
# 70    MFI-50 (SiO2)                            Synthesized            50
# 71   MFI-100 (SiO2)                            Synthesized           100
#
#    mat_core_size_measurement_method mat_core_size_source  \
# 0                               TEM           Experiment
# 1                               TEM           Experiment
# 2                               TEM           Experiment
# 3                               TEM           Experiment
# 4                               TEM           Experiment
# ..                              ...                  ...
# 67                             None           Experiment
# 68                              TEM         Manufacturer
# 69                              TEM         Manufacturer
# 70                              SEM           Experiment
# 71                              SEM        Not specified
#
#                                 mat_hydrodynamic_size  \
# 0                          120±23.8 (Solvent: medium)
# 1   1.38±0.03 (Solvent: culture media); 2.3±0.2 (S...
# 2   40±3 (Solvent: medium); 1.4±0.02 (Solvent: med...
# 3                              28±4 (Solvent: medium)
# 4   30 (Solvent: culture media); 34.9 (Solvent: wa...
# ..                                                ...
# 67         661 (Solvent: water); 1054 (Solvent: DMEM)
# 68  936 (Solvent: serum-free DMEM); 279 (Solvent: ...
# 69  530 (Solvent: DMEM); 1107 (Solvent: DMEM, Seru...
# 70                                               None
# 71                                               None
#
#    mat_hydrodynamic_size_measurement_method mat_hydrodynamic_size_source  \
# 0                                       DLS                   Experiment
# 1                                       DLS                   Experiment
# 2                                       DLS                   Experiment
# 3                                       DLS                   Experiment
# 4                                       DLS                   Experiment
# ..                                      ...                          ...
# 67                                      DLS                   Experiment
# 68                                      DLS                   Experiment
# 69                                      DLS                   Experiment
# 70                                     None                Not specified
# 71                                      DLS                   Experiment
#
#                                    mat_surface_charge  \
# 0                                                None
# 1              1.38±0.03 (pH: 7.4); 2.3±0.2 (pH: 7.4)
# 2                              40±3 (Solvent: medium)
# 3                                                28±4
# 4                                        30 (pH: 7.4)
# ..                                                ...
# 67                             -40.8 (Solvent: water)
# 68  -2.4 (Solvent: DMEM); -7.5 (Solvent: DMEM/5% F...
# 69  -4.0 (Solvent: DMEM); -8.2 (Solvent: DMEM/5% F...
# 70                         -13.2±0.7 (Solvent: water)
# 71                        -12.6±0.8 (Time: immediate)
#
#    mat_surface_charge_measurement_method mat_surface_charge_source  \
# 0                                   None                      None
# 1                         Zeta potential             Not specified
# 2                         Zeta potential                Experiment
# 3                         Zeta potential             Not specified
# 4                         Zeta potential             Not specified
# ..                                   ...                       ...
# 67                        Zeta potential             Not specified
# 68                        Zeta potential                Experiment
# 69                        Zeta potential                Experiment
# 70                        Zeta potential                Experiment
# 71                        Zeta potential                Experiment
#
#    mat_surface_area mat_surface_area_measurement_method  \
# 0       576.23±7.87                                 BET
# 1              None                                None
# 2              None                                None
# 3              None                                None
# 4              None                                None
# ..              ...                                 ...
# 67               38                                 BET
# 68             7.34                                 BET
# 69             1.81                                 BET
# 70        108.3±0.4                                None
# 71         48.1±0.2                                None
#
#    mat_surface_area_source
# 0               Experiment
# 1            Not specified
# 2            Not specified
# 3            Not specified
# 4            Not specified
# ..                     ...
# 67              Experiment
# 68              Experiment
# 69              Experiment
# 70           Not specified
# 71           Not specified
#
# [72 rows x 16 columns]

# %% [markdown]
# # save extracted Pchem data

# %%
import datetime
from pytz import timezone

now = datetime.datetime.now(timezone('Asia/Seoul'))
now = now.strftime("%Y%m%d_%H%M%S")
o = os.path.join(output_folder, "pchem_gtp_output_" + now + ".xlsx")
all_pchem_df.to_excel(o)
print(o + "로 저장되었습니다.")
# Out:
# output_HEY20241118-Eunyong Ha-reproducibility/pchem_gtp_output_20241118_170418.xlsx로 저장되었습니다.

# %% [markdown]
# # Tox data extraction

# %%
print (mats_all_paper_fix)
# Out:
# {'6Z5K86RQ': ['SiO2 (SiO2)'], 'T43GGRMX': ['TiO2 (TiO2)', 'CeO2 (CeO2)', 'ZnO (ZnO)', 'SiO2 (SiO2)'], 'HVPYYSLW': ['MTI5 (TiO2)', 'P25 (TiO2)', 'Nanofilament (TiO2)', 'Hombitan (TiO2)', 'Vive Nano Titania (TiO2)'], '5I96BQWG': ['ZnO nanorods (ZnO)'], 'YNQITCKF': ['P60 (PLGA)', 'P100 (PLGA)', 'P200 (PLGA)', 'T10 (TiO2)', 'T20 (TiO2)', 'T100 (TiO2)'], 'FFWAKGE3': ['Fe2O3 (Fe2O3)', 'In2O3 (In2O3)', 'ZnO (ZnO)', 'ZrO2 (ZrO2)', 'Al2O3 (Al2O3)'], 'HEJLYCVK': ['10SiO2 (SiO2)', '150SiO2 (SiO2)', '500SiO2 (SiO2)'], 'Q4GSNA3A': ['Al2O3 (Al2O3)', 'CeO2 (CeO2)', 'CoO (CoO)', 'Cr2O3 (Cr2O3)', 'Fe2O3 (Fe2O3)', 'Gd2O3 (Gd2O3)', 'HfO2 (HfO2)', 'Ni2O3 (Ni2O3)', 'SiO2 (SiO2)', 'SnO2 (SnO2)', 'Y2O3 (Y2O3)', 'Yb2O3 (Yb2O3)', 'ZrO2 (ZrO2)', 'CuO (CuO)', 'Co3O4 (Co3O4)', 'Fe3O4 (Fe3O4)', 'Sb2O3 (Sb2O3)', 'TiO2 (TiO2)', 'WO3 (WO3)', 'ZnO (ZnO)'], 'USNLP6MR': ['Si50 (SiO2)', 'Si500 (SiO2)'], '5BHP8KES': ['Bulk ZnO (ZnO)', 'Non Ionic ZnO (ZnO)', 'Cationic ZnO (ZnO)', 'Anionic ZnO (ZnO)'], '95ASP9SZ': ['P25 (TiO2)', 'TiO2P25–300 (TiO2)', 'TiO2P25–130 (TiO2)', 'TiO2P25–70 (TiO2)'], 'SKCFUKGT': ['ZnO (ZnO)', 'Fe2O3 (Fe2O3)', 'CuO (CuO)'], 'ASCVGIJU': ['Z-COTE (ZnO)', 'Nanosun (ZnO)', 'Z-COTE HP1 (ZnO)', 'Z-COTE MAX (ZnO)'], 'U27TLPF7': ['ZnO-R8 (ZnO)', 'ZnO-R19 (ZnO)', 'ZnO-S6 (ZnO)', 'ZnO-S25 (ZnO)', 'ZnO-S38 (ZnO)', 'TiO2-A (TiO2)'], 'HAKJAMZY': ['nano-ZnO (ZnO)', 'micro-ZnO (ZnO)'], 'EXQ8I7IY': ['MFI-50 (SiO2)', 'MFI-100 (SiO2)']}

# %%
all_tox_dfs = []
all_gpt_responses = []

for key, value in mats_all_paper_fix.items():

    # make for loop to print each value
    for i in value:
        print(key)

        q = "please pull out cytotoxicity information in the document."
        tox_df = get_sub_answers(i, q, key, tox_info)

        #gpt_res = gpt_responses(key, i, ans_info, ans_core, ans_hydro, ans_s_charge, ans_s_area)
        #all_gpt_responses.append(gpt_res)

        # Append pchem_df to the list
        all_tox_dfs.append(tox_df)

# Combine all pchem_df DataFrames into a single DataFrame
all_tox_df = pd.concat(all_tox_dfs, ignore_index=True)
all_tox_df['ref'] = all_tox_df['key'].map(lambda x: pdf_dict[x] if x in pdf_dict else None)
# Out:
# 6Z5K86RQ
#         key cell_assay cell_classification                  cell_organ  \
# 0  6Z5K86RQ       None      Normal; Cancer  Lung (Met-5A); Lung (A549)
#
#                    cell_species     cell_type
# 0  Human (Met-5A); Human (A549)  Met-5A; A549
# T43GGRMX
#         key cell_assay cell_classification  \
# 0  T43GGRMX        MTT              Cancer
#
#                                       cell_organ  \
# 0  Breast (MCF-7); Lung (BEAS-2B); Cervix (HeLa)
#
#                                    cell_species             cell_type
# 0  Human (MCF-7); Human (BEAS-2B); Human (HeLa)  MCF-7; BEAS-2B; HeLa
# T43GGRMX
#         key cell_assay cell_classification  \
# 0  T43GGRMX   MTT; LDH              Cancer
#
#                                           cell_organ  \
# 0  Breast (MCF-7); Cervix (HeLa); Bronchial tube ...
#
#                                         cell_species  \
# 0  Human (MCF-7); Human (HeLa); Human (BEAS-2B); ...
#
#                     cell_type
# 0  MCF-7; HeLa; BEAS-2B; PC12
# T43GGRMX
#         key cell_assay cell_classification  \
# 0  T43GGRMX        MTT      Cancer; Normal
#
#                                  cell_organ                    cell_species  \
# 0  Breast (MCF-7); Bronchial tube (BEAS-2B)  Human (MCF-7); Human (BEAS-2B)
#
#         cell_type
# 0  MCF-7; BEAS-2B
# T43GGRMX
#         key cell_assay cell_classification  \
# 0  T43GGRMX        MTT              Cancer
#
#                                           cell_organ  \
# 0  Breast (MCF-7); Lung (BEAS-2B); Brain (PC12); ...
#
#                                         cell_species  \
# 0  Human (MCF-7); Human (BEAS-2B); Rat (PC12); Hu...
#
#                     cell_type
# 0  MCF-7; BEAS-2B; PC12; HeLa
# HVPYYSLW
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  HVPYYSLW        MTT              Normal       Lung        Human    IMR-90
# HVPYYSLW
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  HVPYYSLW        MTT              Normal       Lung        Human    IMR-90
# HVPYYSLW
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  HVPYYSLW        MTT              Normal       Lung        Human    IMR-90
# HVPYYSLW
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  HVPYYSLW        MTT              Normal       Lung        Human    IMR-90
# HVPYYSLW
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  HVPYYSLW        MTT              Normal       Lung        Human    IMR-90
# 5I96BQWG
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  5I96BQWG        MTT              Cancer       Lung        Human      A549
# YNQITCKF
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  YNQITCKF       None              Normal     Kidney        Human       HEK
# YNQITCKF
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  YNQITCKF       None              Normal     Kidney        Human       HEK
# YNQITCKF
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  YNQITCKF       None                None       None         None      None
# YNQITCKF
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  YNQITCKF       None              Normal     Kidney        Human       HEK
# YNQITCKF
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  YNQITCKF       None                None       None         None      None
# YNQITCKF
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  YNQITCKF       None              Normal     Kidney        Human       HEK
# FFWAKGE3
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  FFWAKGE3       None                None       None         None      None
# FFWAKGE3
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  FFWAKGE3       None                None       None         None      None
# FFWAKGE3
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  FFWAKGE3       None                None       None         None      None
# FFWAKGE3
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  FFWAKGE3       None                None       None         None      None
# FFWAKGE3
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  FFWAKGE3       None                None       None         None      None
# HEJLYCVK
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  HEJLYCVK       None                None       None         None      None
# HEJLYCVK
#         key cell_assay cell_classification   cell_organ cell_species  \
# 0  HEJLYCVK       None              Normal  Endothelial        Human
#
#                  cell_type
# 0  Human endothelial cells
# HEJLYCVK
#         key cell_assay cell_classification   cell_organ cell_species  \
# 0  HEJLYCVK        MTT              Normal  Endothelial        Human
#
#                  cell_type
# 0  Human endothelial cells
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key     cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# Q4GSNA3A
#         key         cell_assay cell_classification  \
# 0  Q4GSNA3A  MTS; ATP; LDH; PI              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# USNLP6MR
#         key cell_assay cell_classification      cell_organ cell_species  \
# 0  USNLP6MR       None              Normal  Bronchial tube        Human
#
#   cell_type
# 0   BEAS-2B
# USNLP6MR
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  USNLP6MR       None              Normal       Lung        Human   BEAS-2B
# 5BHP8KES
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  5BHP8KES   WST; LDH              Cancer       None        Human     THP-1
# 5BHP8KES
#         key       cell_assay cell_classification cell_organ cell_species  \
# 0  5BHP8KES  WST; LDH; 7-AAD              Cancer       None        Human
#
#   cell_type
# 0     THP-1
# 5BHP8KES
#         key     cell_assay cell_classification cell_organ cell_species  \
# 0  5BHP8KES  WST; LDH; MTT              Cancer       None        Human
#
#   cell_type
# 0     THP-1
# 5BHP8KES
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  5BHP8KES   WST; LDH              Cancer       None        Human     THP-1
# 95ASP9SZ
#         key cell_assay cell_classification                        cell_organ  \
# 0  95ASP9SZ       None      Cancer; Normal  Liver (HepG2); Skin (Langerhans)
#
#                         cell_species          cell_type
# 0  Human (HepG2); Human (Langerhans)  HepG2; Langerhans
# 95ASP9SZ
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  95ASP9SZ       None                None       None         None      None
# 95ASP9SZ
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  95ASP9SZ       None              Normal       None         None      None
# 95ASP9SZ
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  95ASP9SZ       None                None       None         None      None
# SKCFUKGT
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  SKCFUKGT       None              Normal    Cardiac        Human     HCMEC
# SKCFUKGT
#         key cell_assay cell_classification                     cell_organ  \
# 0  SKCFUKGT       None              Normal  Cardiac (HCMECs); Lung (HELF)
#
#                    cell_species     cell_type
# 0  Human (HCMECs); Human (HELF)  HCMECs; HELF
# SKCFUKGT
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  SKCFUKGT       None              Normal    Cardiac        Human     HCMEC
# ASCVGIJU
#         key cell_assay cell_classification  \
# 0  ASCVGIJU       None              Cancer
#
#                              cell_organ               cell_species  \
# 0  Larynx (HEp-2); Adrenal Gland (PC12)  Human (HEp-2); Rat (PC12)
#
#      cell_type
# 0  HEp-2; PC12
# ASCVGIJU
#         key cell_assay cell_classification                    cell_organ  \
# 0  ASCVGIJU       None      Cancer; Normal  Larynx (HEp-2); Brain (PC12)
#
#                 cell_species    cell_type
# 0  Human (HEp-2); Rat (PC12)  HEp-2; PC12
# ASCVGIJU
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  ASCVGIJU       None              Cancer     Larynx        Human     HEp-2
# ASCVGIJU
#         key   cell_assay cell_classification  \
# 0  ASCVGIJU  CytoTox-ONE              Cancer
#
#                                           cell_organ  \
# 0  Larynx (HEp-2); Brain (PC12); Colon (Human col...
#
#                                         cell_species  \
# 0  Human (HEp-2); Rat (PC12); Human (Human colon ...
#
#                                cell_type
# 0  HEp-2; PC12; Human colon cancer cells
# U27TLPF7
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  U27TLPF7        MTT              Cancer       Lung        Human      A549
# U27TLPF7
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  U27TLPF7        MTT              Cancer       Lung        Human      A549
# U27TLPF7
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  U27TLPF7        MTT              Cancer       Lung        Human      A549
# U27TLPF7
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  U27TLPF7        MTT              Cancer       Lung        Human      A549
# U27TLPF7
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  U27TLPF7  MTT; IL-8              Cancer       Lung        Human      A549
# U27TLPF7
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  U27TLPF7        MTT              Cancer       Lung        Human      A549
# HAKJAMZY
#         key cell_assay cell_classification    cell_organ cell_species  \
# 0  HAKJAMZY  MTT; IL-8              Cancer  Monoblastoid        Human
#
#   cell_type
# 0     THP-1
# HAKJAMZY
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  HAKJAMZY  MTT; IL-8                None       None         None      None
# EXQ8I7IY
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  EXQ8I7IY       None                None       None         None      None
# EXQ8I7IY
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  EXQ8I7IY       None                None       None         None      None

# %%
all_tox_df
# Out:
#          key cell_assay cell_classification  \
# 0   6Z5K86RQ       None      Normal; Cancer
# 1   T43GGRMX        MTT              Cancer
# 2   T43GGRMX   MTT; LDH              Cancer
# 3   T43GGRMX        MTT      Cancer; Normal
# 4   T43GGRMX        MTT              Cancer
# ..       ...        ...                 ...
# 67  U27TLPF7        MTT              Cancer
# 68  HAKJAMZY  MTT; IL-8              Cancer
# 69  HAKJAMZY  MTT; IL-8                None
# 70  EXQ8I7IY       None                None
# 71  EXQ8I7IY       None                None
#
#                                            cell_organ  \
# 0                          Lung (Met-5A); Lung (A549)
# 1       Breast (MCF-7); Lung (BEAS-2B); Cervix (HeLa)
# 2   Breast (MCF-7); Cervix (HeLa); Bronchial tube ...
# 3            Breast (MCF-7); Bronchial tube (BEAS-2B)
# 4   Breast (MCF-7); Lung (BEAS-2B); Brain (PC12); ...
# ..                                                ...
# 67                                               Lung
# 68                                       Monoblastoid
# 69                                               None
# 70                                               None
# 71                                               None
#
#                                          cell_species  \
# 0                        Human (Met-5A); Human (A549)
# 1        Human (MCF-7); Human (BEAS-2B); Human (HeLa)
# 2   Human (MCF-7); Human (HeLa); Human (BEAS-2B); ...
# 3                      Human (MCF-7); Human (BEAS-2B)
# 4   Human (MCF-7); Human (BEAS-2B); Rat (PC12); Hu...
# ..                                                ...
# 67                                              Human
# 68                                              Human
# 69                                               None
# 70                                               None
# 71                                               None
#
#                      cell_type  \
# 0                 Met-5A; A549
# 1         MCF-7; BEAS-2B; HeLa
# 2   MCF-7; HeLa; BEAS-2B; PC12
# 3               MCF-7; BEAS-2B
# 4   MCF-7; BEAS-2B; PC12; HeLa
# ..                         ...
# 67                        A549
# 68                       THP-1
# 69                        None
# 70                        None
# 71                        None
#
#                                                   ref
# 0   Michael Berg 등 - 2013 - Comparative cytologica...
# 1                                            22303956
# 2                                            22303956
# 3                                            22303956
# 4                                            22303956
# ..                                                ...
# 67  Hsiao 그리고 Huang - 2011 - Effects of various ph...
# 68                                           24078789
# 69                                           24078789
# 70                                           23103338
# 71                                           23103338
#
# [72 rows x 7 columns]

# %% [markdown]
# # Tox data extraction results

# %%
import datetime
from pytz import timezone

now = datetime.datetime.now(timezone('Asia/Seoul'))
now = now.strftime("%Y%m%d_%H%M%S")
o = os.path.join(output_folder, "tox_gtp_output_" + now + ".xlsx")
all_tox_df.to_excel(o)
print(o + "로 저장되었습니다.")
# Out:
# output_HEY20241118-Eunyong Ha-reproducibility/tox_gtp_output_20241118_170742.xlsx로 저장되었습니다.

# %% [markdown]
# # Tokens and cost

# %%
cost_list = []
for key, value in openai_cb.items():
    #print(value.total_cost)
    cost_dict = {}
    cost_dict["Date Time"] = key
    cost_dict["Total tokens"] = value.total_tokens
    cost_dict["Total cost ($)"] = value.total_cost
    cost_list.append(cost_dict)

cost_df = pd.DataFrame(cost_list)
sums = cost_df.select_dtypes(include='number').sum()
sums_dict = {"Date Time": "Total", "Total tokens": sums["Total tokens"], "Total cost ($)": sums["Total cost ($)"]}

# %%
cost_df = pd.concat([cost_df, pd.DataFrame([sums_dict])])
cost_df
# Out:
#            Date Time  Total tokens  Total cost ($)
# 0    20241118_164948        1374.0        0.006950
# 1    20241118_164952        1497.0        0.007785
# 2    20241118_164954        1477.0        0.007785
# 3    20241118_164956        1425.0        0.007215
# 4    20241118_164958        1467.0        0.007725
# ..               ...           ...             ...
# 516  20241118_170735        1664.0        0.008910
# 517  20241118_170737        1659.0        0.008835
# 518  20241118_170739        1438.0        0.007680
# 519  20241118_170741        1438.0        0.007680
# 0              Total      880790.0        4.623660
#
# [521 rows x 3 columns]

# %%
import datetime
from pytz import timezone

now = datetime.datetime.now(timezone('Asia/Seoul'))
now = now.strftime("%Y%m%d_%H%M%S")
o = os.path.join(output_folder, "token_and_cost_" + now + ".xlsx")
cost_df.to_excel(o)
print("saved as " + o + ".")
# Out:
# output_HEY20241118-Eunyong Ha-reproducibility/token_and_cost_20241118_170742.xlsx로 저장되었습니다.

# %%
# 마지막 셀에 추가
notebook_end_time = time.time()
print(f"total running time: {notebook_end_time - notebook_start_time}sec")
# Out:
# 노트북 전체 실행 시간: 1173.8525257110596초
