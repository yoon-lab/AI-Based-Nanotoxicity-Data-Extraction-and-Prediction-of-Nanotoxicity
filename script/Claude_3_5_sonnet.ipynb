# %%
import importlib.metadata

    # LangChain check package version
try:
    version = importlib.metadata.version('langchain')
    print(f"LangChain version: {version}")
except importlib.metadata.PackageNotFoundError:
    print("LangChain package is not installed.")

    # LangChain-core check package version
try:
    version = importlib.metadata.version('langchain-core')
    print(f"LangChain-core version: {version}")
except importlib.metadata.PackageNotFoundError:
    print("LangChain-core package is not installed.")
# Out:
# LangChain version: 0.2.14

# %% [markdown]
# # 0. Enter username (output folder will made for this name)

# %%
user_name = "user_name"

# %%
import time
notebook_start_time = time.time()

# %% [markdown]
# # 1. Basic prompt template of LangChain enviroment

# %%
template = """
You are a data analyst specializing in nano-toxicity.
Your task is extracting data about the physicochemical and cytotoxic properties of nanomaterials used in the research paper.
Use the following pieces of instruction and format to answer the user's questions.
Don't be lazy.
Be very strict and answer the question very accurate and scientific manner.
If data is not specified in the paper, just answer 'None'.
Do not use a full sentence.
Please provide the output as a valid JSON object without any additional explanations.
Context: {context}
Question: {question}
Format instruction: {format_instructions}
"""

# %% [markdown]
# # 2. Material data extraction prompt

# %%
q_mat = """
Just answer with following format: 'Nanomaterial name (Nanomaterial type)'. Do not use a full sentence.
Question: What nanoparticles were used in the characterization experiments in the research paper? Refer to the following descriptions.
Description 1. Provide the nanoparticles that were used for core size(i.e. primary size, nominal size) or hydrodynamic size(i.e. Z-average size) or surface charge(i.e. zeta potential) or surface area in the research paper.
Description 2. Provide information on all the nanoparticles actually used in the authors' experiments. Do not include nanoparticles used in other papers (i.e., mentioned in the reference) in your answer.
Description 3. If there were multiple nanoparticles of the same type, the author would have named them differently. What did the author name them?
Description 4. Write the name of the nanoparticle followed by its type in chemical formula within parentheses.
Description 5. Several examples of the format.
-Written in the document: Al2O3, GO, ZnO, SiO2, Fe2O3 (normal form), Response: Al2O3 (Al2O3), GO (GO), ZnO (ZnO), SiO2 (SiO2), Fe2O3 (Fe2O3).
-Written in the document: T10, T100 (labeled differently according to 'size'), Response: T10 (TiO2), T100 (TiO2).
-Written in the document: ZnAc, ZnChl (ZnO-Acetate, ZnO-Chloride; labeled differently according to 'chemical'), Response: ZnAc (ZnO), ZnChl (ZnO).
-Written in the document: TiO2-PVP, TiO2-Citrate (labeled differently according to 'coating'), Response: TiO2-PVP (TiO2), TiO2-Citrate (TiO2).
-Written in the document: P25, Nanofilament (labeled differently according to 'manufacturer'), Response: P25 (TiO2), Nanofilament (TiO2).
-Written in the document: CuO-USA, CuO-UK (labeled differently according to 'location'), Response: CuO-USA (CuO), CuO-UK (CuO).
Description 6. Do not omit the information.
Description 7. Do not write 'NP' or 'nanoparticles' followed by nanoparticles'name
"""

# %% [markdown]
# # 3. PChem/Tox data extraction prompt
# - Pchem
# - Tox

# %%
import pprint
from typing import Any, Dict
import datetime
from pytz import timezone

import pandas as pd
from langchain.output_parsers import PydanticOutputParser
#from langchain.output_parsers import PandasDataFrameParser

from langchain.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field, validator

class pchem_product_info(BaseModel):
    mat_name: str = Field(description="Question: What nanoparticles were used in the characterization experiments in the research paper? Refer to the following descriptions. Description 0. Do not include metal nanoparticles such as Silver (Ag) or Gold (Au). 1. Provide the nanoparticles that were used for core size(i.e. primary size, nominal size) or hydrodynamic size(i.e. Z-average size) or surface charge(i.e. zeta potential) or surface area in the research paper. Description 2. Provide information on all the nanoparticles actually used in the authors' experiments. Do not include nanoparticles used in other papers (i.e., mentioned in the reference) in your answer. Description 3. If there were multiple nanoparticles of the same type, the author would have named them differently. What did the author name them? Description 4. Write the name of the nanoparticle followed by its type in chemical formula within parentheses.   Description 5. Several examples of the format. -Written in the document: Al2O3 NPs, ZnO, SiO2, Fe2O3 (normal form), Response: Al2O3 (Al2O3), ZnO (ZnO), SiO2 (SiO2), Fe2O3 (Fe2O3). -Written in the document: T10, T100 (labeled differently according to 'size'), Response: T10 (TiO2), T100 (TiO2). -Written in the document: ZnAc, ZnChl (ZnO-Acetate, ZnO-Chloride; labeled differently according to 'chemical'), Response: ZnAc (ZnO), ZnChl (ZnO). -Written in the document: TiO2-PVP, TiO2-Citrate (labeled differently according to 'coating'), Response: TiO2-PVP (TiO2), TiO2-Citrate (TiO2). -Written in the document: P25, Nanofilament (labeled differently according to 'manufacturer'), Response: P25 (TiO2), Nanofilament (TiO2). -Written in the document: CuO-USA, CuO-UK (labeled differently according to 'location'), Response: CuO-USA (CuO), CuO-UK (CuO). Description 6. Do not omit the information. Description 7. Do not write 'NP' or 'nanoparticles' followed by nanoparticles'name")
    def to_dict(self):
        return {"mat_name": self.mat_name}

class pchem_mat_synthesis(BaseModel):
    mat_synthesis: str = Field(description="The following nanoparticles were synthesized by researcher? or commercially available? If nanoparticles were synthesized, just answer 'Synthesized'. If nanoparticles were commercially available, just answer 'Commercially available (with cat# or product # in parentheses).'")
    def to_dict(self):
        return {"mat_synthesis": self.mat_synthesis}

class pchem_core_size(BaseModel):
    mat_core_size: str = Field(description="What is the value of core size or core size distribution (i.e. primary size, nominal size) of each material? Refer to the following format to answer. 0. TEM, SEM, AFM size. 1. Do not include unit. 2. Do not use a full sentence. 3. If there is no value, assign 'None'. 4. Do not include calculated size. 5. If the values are represented as a range, they are represented in the following format: value1-value2. ex) 50-100. 6. If the values are represented with an error rate '±', they are represented in the following format: value±error rate. ex) 35±10.")
    def to_dict(self):
        return {"mat_core_size": self.mat_core_size}

class pchem_hydrodynamic_size(BaseModel):
    mat_hydrodynamic_size: str = Field(description="What is the value of hydrodynamic size (i.e., Z-average size, size in media) of each material? Please provide details on the sizes under various conditions or in different media. 0. DLS size. 1. Do not include unit. 2. Do not include an explanation about hydrodynamic size. Just give me the value. 3. Do not use a full sentence. 4. If there is no value, assign 'None'. 5. If multiple values exist for each material, divide the value using ';', add parentheses after the value, and write the conditions in the parentheses. 6. Please refer to the following format when you write down the conditions in parentheses. Format: [Classification: detailed conditions]. ex) 50 (Solvent: water); 100 (Solvent: medium), 30 (Time: 2 h); 50 (Time: 24 h). Kind of Classification: Solvent, Time, Concentration, pH.7. If there are both water and culture media conditions, only the culture media condition is selected. However, if there are only conditions taken in water, select conditions taken in water. If t 8. If the values are represented as a range, they are represented in the following format: value1-value2. ex) 50-100. 9. If the values are represented with an error rate '±', they are represented in the following format: value±error rate. ex) 35±10.")
    def to_dict(self):
        return {"mat_hydrodynamic_size": self.mat_hydrodynamic_size}

class pchem_surface_charge(BaseModel):
    mat_surface_charge: str = Field(description="What is the value of surface charge (i.e., Zeta potential) of each material? Please provide details on the sizes under various conditions or in different media. 1. Do not include unit. 2. Do not include an explanation about hydrodynamic size. Just give me the value. 3. Do not use a full sentence. 4. If there is no value, assign 'None'. 5. If multiple values exist for each material, divide the value using ';', add parentheses after the value, and write the conditions in the parentheses. 6. Please refer to the following format when you write down the conditions in parentheses. Format: [Classification: detailed conditions]. ex) -10 (Solvent: water); 21 (Solvent: medium), 30 (Time: 2 h); 50 (Time: 24 h). Kind of Classification: Solvent, Time, Concentration, pH. 7. If the values are represented as a range, they are represented in the following format: value1-value2. ex) 50-100. 8. If the values are represented with an error rate '±', they are represented in the following format: value±error rate. ex) 35±10. 9. If there are both water and culture media conditions, only the culture media condition is selected. However, if there are only conditions taken in water, select conditions taken in water.")
    def to_dict(self):
        return {"mat_surface_charge": self.mat_surface_charge}

class pchem_surface_area(BaseModel):
    mat_surface_area: str = Field(description="What is the value of surface area of each material? Refer to the following format to answer. 1. Do not include unit. 2. Do not use a full sentence. 3. If there is no value, assign 'None'. 4. Do not include calculated size. 5. If the values are represented as a range, they are represented in the following format: value1-value2. ex) 50-100. 6. If the values are represented with an error rate '±', they are represented in the following format: value±error rate. ex) 35±10.")
    def to_dict(self):
        return {"mat_surface_area": self.mat_surface_area}

# %%
class tox_info(BaseModel):
    cell_type: str = Field(description="What cell lines were used in the cell viability assay? 1. Do not use a full sentence. 2. Please provide the abbreviation form of the cell name. ex) A549, THP-1, MRC-5, EA.hy926, BEAS-2B, HaCaT, L929, U87, etc. 3. If multiple cell lines were used, divide the value using ';'. ex) A549; THP-1; MRC-5.")
    cell_species: str = Field(description="What species the cell line originated from? 1. Do not use a full sentence. 2. Please refer to the following form. ex) Human, Rabbit, Mouse, Pig, etc. 3. If multiple cell lines were used and their species are different,  divide the value using ';' and write the name of the cell species followed by its cell type within parentheses. ex) Human (A549); Mouse (L929).")
    cell_organ: str = Field(description="What organ the cell line originated from? 1. Do not use a full sentence. 2. Please refer to the following form. ex) Lung, Breast, Kidney, Brain, Liver, Bronchial tube, Prostate, Spleen, etc. 3. If multiple cell lines were used and their organs are different, divide the value using ';' and write the name of the cell species followed by its cell type within parentheses. ex) Lung (A549); Fibroblast (L929).")
    cell_assay: str = Field(description="Which cell viability assays or cytotoxicity assay were conducted in this paper? 1. Do not use a full sentence. 2. Only reference the following cell viability assays, and if none, assign as 'None'. 2. Please refer to the following form. ex) CCK-8, MTT, MTS, WST, Alamar blue, CellTiter-Glo, Neutral Red, NRU, Trypan blue, XTT, Calcein-AM, BrdU, EdU, Propidium iodide, Hoechst33342 assays. 3. If multiple cell viability assays were used, divide the value using ';'. ex) MTT; MTS; CCK-8.")
    cell_classification: str = Field(description="Please determine the cell type: whether it is a normal cell or a cancer cell? 1. Do not use a full sentence. 2. Just answer, 'Normal' or 'Cancer'.")
    def to_dict(self):
        return {"cell_type": self.cell_type, "cell_species": self.cell_species, "cell_organ": self.cell_organ, "cell_assay": self.cell_assay,"cell_classification": self.cell_classification}

# %% [markdown]
# # 4. Connect LangChain with Zotero
# - Zotero collection cionfiguration
# - Set directory of output and zotero pdf download
# - Extract data from Zotero
# - Get PDF file list and IDs

# %%
##Zotero collection configuration

import os
from os.path import join, basename, splitext
import subprocess
from glob import glob
from shutil import copy
from random import shuffle, seed

from pyzotero import zotero

zot = zotero.Zotero(library_id, 'library_type', 'zotero_api_key') ## fill zotero.Zoter(library_id, library_type, zotero_api_key)

collections = {c['data']['name']: c for c in zot.collections()}

collection_names = []
for key, value in collections.items():
    #print(key)
    collection_names.append(key)

collection_names
# Out:
# ['remove123456',
#  'remove12345',
#  'remove123',
#  'PchemScore_1',
#  'oxide af filter5',
#  'oxide af filter3',
#  'oxide af filter2',
#  'pmfilter',
#  'oxide af a',
#  'oxide af filter1',
#  'oxide af filter',
#  'WOS 8',
#  'WOS 7',
#  'WOS 6',
#  'WOS 5',
#  'WOS 4',
#  'WOS 3',
#  'WOS 1',
#  'WOS 2',
#  'WOS 0',
#  'PUBMED 9',
#  'PUBMED 8',
#  'PUBMED 7',
#  'PUBMED 6',
#  'PUBMED 2',
#  'PUBMED 1',
#  'PUBMED 5',
#  'PUBMED 4',
#  'PUBMED 3',
#  'PUBMED 0',
#  'testa',
#  'new pdf',
#  'Oxide af 2018 WOS',
#  'Oxide af 2018 PUBMED',
#  'Ha 1a-1',
#  'Metal oxide after 2018 wos',
#  'Metal oxide after 2018 pubmed',
#  'test1',
#  'Metal External dataset',
#  'ddd',
#  'Trinh_test',
#  'External dataset',
#  'Ha 1d',
#  'Ha 1c',
#  'Ha 1b',
#  'Ha 1a',
#  'Ha 3b',
#  '2025_DB',
#  'TrinhB',
#  'Ha 3a',
#  'Ha 2',
#  'TrinhA',
#  'training set oxide 3',
#  'training set metal 2',
#  'training set oxide 2',
#  'training set metal',
#  'test set for chatGPT',
#  'traning set for chatGPT',
#  'Ha IIIa',
#  'Ha II',
#  'Ha I',
#  'Xiao Metal',
#  'Ha Oxide 2018',
#  'Xiao Oxide',
#  'Trinh Metal 2018',
#  'kriss.s2nano.org : after 2018',
#  'qntr.s2nno.org : before2018',
#  'prof collection',
#  'training set oxide',
#  'automation for Nanotox']

# %%
selected_collection = "enter_collection_name" # copy and pase collection name
pdf_folder = "/home/pdf_" + selected_collection.replace(" ", "_")
print("PDF files are stored at "+ pdf_folder + ".")
# Out:
# PDF 파일들은 /home/pdf_remove123456에 저장됩니다.

# %%
## PDF 파일 폴더와 output 폴더 설정

import os

def create_folder(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Folder created at {folder_path}")
    else:
        print(f"Folder already exists at {folder_path}")

output_folder = "output_" + user_name
create_folder(output_folder)
create_folder(pdf_folder)
# Out:
# Folder already exists at output_HEY20241019-Eunyong Ha-Claude 3.5 sonnet-Ha1
# Folder already exists at /home/pdf_remove123456

# %%
## extract collection data from zotero

import os
from os.path import join, basename, splitext
import subprocess
from glob import glob
from shutil import copy
from random import shuffle, seed

from pyzotero import zotero
zot = zotero.Zotero(library_id, 'library_type', 'zotero_api_key') ## fill zotero.Zoter(library_id, library_type, zotero_api_key)

collections = {c['data']['name']: c for c in zot.collections()}
collection = collections[selected_collection]
key = collection['key']

items = [d for d in zot.everything(zot.collection_items(key))]

pdf_dict = {}
for item in items:
    pdf_dict[item['data']['key']] = item['data']['title']

### if there is 'title' error use this code
#for item in items:
#    # Check if the 'title' key exists in the item['data']
#    if 'title' in item['data']:
#        pdf_dict[item['data']['key']] = item['data']['title']
#    else:
#        print(f"Item {item['data']['key']} does not have a title.")

# Iterate over items in the collection
for item in items:
    title = item['data'].get('title', 'No Title')
    print(f"\nProcessing item: {title}")

    # Ensure we're not processing non-attachment items
    if item['data'].get('itemType') != 'attachment':
        try:
            children = [c for c in zot.children(item['key'])]
            print(f"Found {len(children)} children for item '{title}'")

            # Check for PDFs among the children
            pdfs = [c for c in children if c['data'].get('contentType') == 'application/pdf']

            if not children:
                print(f"Missing documents for: {title}")
            elif not pdfs:
                print(f"No PDFs found for: {title}")
            elif len(pdfs) > 1:
                print(f"Too many PDFs for: {title}")
            else:
                doc = pdfs[0]
                print(f"PDF found: {doc['data']['filename']}")

                pdf_file_path = os.path.join(pdf_folder, f"{doc['key']}.pdf")

                # Check if the PDF already exists, and download if it doesn't
                if not os.path.exists(pdf_file_path):
                    zot.dump(doc['key'], pdf_file_path, pdf_folder)
                    print(f"{pdf_file_path} is downloaded.")
                else:
                    print(f"{pdf_file_path} already exists.")

        except Exception as e:
            print(f"Error processing item {title}: {e}")
    else:
        print(f"Skipped non-PDF entry: {title}")
# Out:
# Processing item: 19922763
# Skipped non-PDF entry: 19922763
#
# Processing item: Oxidative stress and apoptosis induced by nanosized titanium dioxide in PC12 cells
# Found 1 children for item 'Oxidative stress and apoptosis induced by nanosized titanium dioxide in PC12 cells'
# PDF found: 19922763.pdf
# /home/pdf_remove123456/WZ62GXAT.pdf already exists.
#
# Processing item: Use of metal oxide nanoparticle band gap to develop a predictive paradigm for oxidative stress and acute pulmonary inflammation
# Found 1 children for item 'Use of metal oxide nanoparticle band gap to develop a predictive paradigm for oxidative stress and acute pulmonary inflammation'
# PDF found: 22502734.pdf
# /home/pdf_remove123456/DUR86VJI.pdf already exists.
#
# Processing item: Effects of iron oxide nanoparticle labeling on human endothelial cells
# Found 1 children for item 'Effects of iron oxide nanoparticle labeling on human endothelial cells'
# PDF found: 22776829.pdf
# /home/pdf_remove123456/U5TWM8XC.pdf already exists.
#
# Processing item: Cellular internalization and detailed toxicity analysis of protein-immobilized iron oxide nanoparticles
# Found 1 children for item 'Cellular internalization and detailed toxicity analysis of protein-immobilized iron oxide nanoparticles'
# PDF found: 24788586.pdf
# /home/pdf_remove123456/JST2FHKJ.pdf already exists.
#
# Processing item: Effects of Fe3O4 Magnetic Nanoparticles on A549 Cells
# Found 1 children for item 'Effects of Fe3O4 Magnetic Nanoparticles on A549 Cells'
# PDF found: 23892599.pdf
# /home/pdf_remove123456/95KXTZVR.pdf already exists.
#
# Processing item: Mitochondrial electron transport chain identified as a novel molecular target of SPIO nanoparticles mediated cancer-specific cytotoxicity
# Found 1 children for item 'Mitochondrial electron transport chain identified as a novel molecular target of SPIO nanoparticles mediated cancer-specific cytotoxicity'
# PDF found: 26773667.pdf
# /home/pdf_remove123456/W5DHTC2Z.pdf already exists.
#
# Processing item: Enhanced cellular uptake of aminosilane-coated superparamagnetic iron oxide nanoparticles in mammalian cell lines
# Found 1 children for item 'Enhanced cellular uptake of aminosilane-coated superparamagnetic iron oxide nanoparticles in mammalian cell lines'
# PDF found: 22393292.pdf
# /home/pdf_remove123456/9843ENP3.pdf already exists.
#
# Processing item: Synthesis of small-sized, porous, and low-toxic magnetite nanoparticles by thin POSS silica coating
# Found 1 children for item 'Synthesis of small-sized, porous, and low-toxic magnetite nanoparticles by thin POSS silica coating'
# PDF found: 25630810.pdf
# /home/pdf_remove123456/I3MS5H2K.pdf already exists.
#
# Processing item: Hyaluronic acid-modified hydrothermally synthesized iron oxide nanoparticles for targeted tumor MR imaging
# Found 1 children for item 'Hyaluronic acid-modified hydrothermally synthesized iron oxide nanoparticles for targeted tumor MR imaging'
# PDF found: 24462358.pdf
# /home/pdf_remove123456/8A3RUDZD.pdf already exists.
#
# Processing item: Synthesis and characterization of PEG-iron oxide core-shell composite nanoparticles for thermal therapy
# Found 1 children for item 'Synthesis and characterization of PEG-iron oxide core-shell composite nanoparticles for thermal therapy'
# PDF found: 24094173.pdf
# /home/pdf_remove123456/UK8SV8XM.pdf already exists.
#
# Processing item: Effect of ultrasmall superparamagnetic iron oxide nanoparticles (Ferumoxtran-10) on human monocyte-macrophages in vitro
# Found 1 children for item 'Effect of ultrasmall superparamagnetic iron oxide nanoparticles (Ferumoxtran-10) on human monocyte-macrophages in vitro'
# PDF found: 17178155.pdf
# /home/pdf_remove123456/KT5U49ZB.pdf already exists.
#
# Processing item: 17178155.pdf
# Skipped non-PDF entry: 17178155.pdf
#
# Processing item: 26773667.pdf
# Skipped non-PDF entry: 26773667.pdf
#
# Processing item: 22393292.pdf
# Skipped non-PDF entry: 22393292.pdf
#
# Processing item: 25630810.pdf
# Skipped non-PDF entry: 25630810.pdf
#
# Processing item: 24094173.pdf
# Skipped non-PDF entry: 24094173.pdf
#
# Processing item: 24462358.pdf
# Skipped non-PDF entry: 24462358.pdf
#
# Processing item: 23892599.pdf
# Skipped non-PDF entry: 23892599.pdf
#
# Processing item: 24788586.pdf
# Skipped non-PDF entry: 24788586.pdf
#
# Processing item: 22776829.pdf
# Skipped non-PDF entry: 22776829.pdf
#
# Processing item: 22502734.pdf
# Skipped non-PDF entry: 22502734.pdf

# %%
## Get PDF file list and IDs

pdf_files = []

for file_path in os.listdir(pdf_folder):
    if os.path.isfile(os.path.join(pdf_folder, file_path)):
        pdf_files.append(os.path.join(pdf_folder, file_path))

print(pdf_files)

# get pdf ids and store as pdf_ids
pdf_ids = []
for file_path in pdf_files:
    # get base name of file_pafth and remove .pdf
    base_name = os.path.basename(file_path)
    base_name = os.path.splitext(base_name)[0]
    pdf_ids.append(base_name)
print(pdf_ids)
# Out:
# ['/home/pdf_remove123456/WZ62GXAT.pdf', '/home/pdf_remove123456/UK8SV8XM.pdf', '/home/pdf_remove123456/JST2FHKJ.pdf', '/home/pdf_remove123456/KT5U49ZB.pdf', '/home/pdf_remove123456/95KXTZVR.pdf', '/home/pdf_remove123456/8A3RUDZD.pdf', '/home/pdf_remove123456/DUR86VJI.pdf', '/home/pdf_remove123456/U5TWM8XC.pdf', '/home/pdf_remove123456/I3MS5H2K.pdf', '/home/pdf_remove123456/9843ENP3.pdf', '/home/pdf_remove123456/W5DHTC2Z.pdf']
# ['WZ62GXAT', 'UK8SV8XM', 'JST2FHKJ', 'KT5U49ZB', '95KXTZVR', '8A3RUDZD', 'DUR86VJI', 'U5TWM8XC', 'I3MS5H2K', '9843ENP3', 'W5DHTC2Z']

# %% [markdown]
# # 5. Claude 3.5 Sonnet with LangChain

# %%
from langchain.embeddings import OpenAIEmbeddings
OPENAI_API_KEY="openai_api_key"
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY, model ="text-embedding-3-large")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:141: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
## Generate embeddings & save as files

# %%
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import PyPDFium2Loader
import os


error_files = []

def get_pdf_text(file_pafth):
    try:
        # get base name of file_pafth and remove .pdf
        base_name = os.path.basename(file_pafth)
        base_name = os.path.splitext(base_name)[0]
        print(base_name)

        em_path = "/home/claude_em24080199/" + base_name + "_claude" ## embedding result save path
        if not os.path.exists(em_path):
            # Load the PDF document
            load = PyPDFium2Loader(file_pafth)
            document = load.load()

            # Split text into chunks
            text_splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=50)
            texts = text_splitter.split_documents(document)

            # Embed the documents using FAISS
            db = FAISS.from_documents(texts, embeddings)

            # Save the FAISS index locally
            db.save_local(em_path)
            print(f"{em_path} is generated.")
        else:
            print(f"{em_path} already exists")
    except Exception as e:
        # Handle any exceptions and continue processing the next file
        print(f"Error processing {file_pafth}: {e}")
        # 오류가 발생한 파일명을 리스트에 추가
        error_files.append(file_pafth)

# Run get_pdf_text for all pdf_files
for file_path in pdf_files:
    get_pdf_text(file_path)
# Out:
# WZ62GXAT
# /usr/local/lib/python3.10/dist-packages/pypdfium2/_helpers/textpage.py:80: UserWarning: get_text_range() call with default params will be implicitly redirected to get_text_bounded()
#   warnings.warn("get_text_range() call with default params will be implicitly redirected to get_text_bounded()")
# /home/claude_em24080199/WZ62GXAT_claude is generated.
# UK8SV8XM
# /home/claude_em24080199/UK8SV8XM_claude is generated.
# JST2FHKJ
# /home/claude_em24080199/JST2FHKJ_claude is generated.
# KT5U49ZB
# /home/claude_em24080199/KT5U49ZB_claude is generated.
# 95KXTZVR
# /home/claude_em24080199/95KXTZVR_claude is generated.
# 8A3RUDZD
# /home/claude_em24080199/8A3RUDZD_claude is generated.
# DUR86VJI
# /home/claude_em24080199/DUR86VJI_claude is generated.
# U5TWM8XC
# /home/claude_em24080199/U5TWM8XC_claude is generated.
# I3MS5H2K
# /home/claude_em24080199/I3MS5H2K_claude is generated.
# 9843ENP3
# /home/claude_em24080199/9843ENP3_claude is generated.
# W5DHTC2Z
# /home/claude_em24080199/W5DHTC2Z_claude is generated.

# %%
if error_files:
    print("The following files encountered errors:")
    for error_file in error_files:
        print(error_file)
else:
    print("No errors encountered.")
# Out:
# No errors encountered.

# %%
# 마지막 셀에 추가
notebook_end_time = time.time()
print(f"total notebook running time : {notebook_end_time - notebook_start_time}sec")
# Out:
# 노트북 전체 실행 시간: 55.63834095001221초

# %%
from langchain_anthropic.chat_models import ChatAnthropic
from langchain.vectorstores import FAISS
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain_core.prompts import ChatPromptTemplate
from langchain.output_parsers import CommaSeparatedListOutputParser
from langchain.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough


chat = ChatAnthropic(model="claude-3-5-sonnet-20240620", api_key="VOYAGE_API_KEY",
                     temperature=0)

# %%
from langchain.callbacks import get_openai_callback

openai_cb = {}

def get_answer(doc_id, q, parser):
    db = FAISS.load_local("/home/claude_em24080199/" + doc_id + "_claude", embeddings,allow_dangerous_deserialization=True)
    prompt = PromptTemplate(
        template=template,
        input_variables=['context', 'question'],
        partial_variables = {"format_instructions": parser.get_format_instructions()},)
    retriever = db.as_retriever(search_kwargs={'k': 10})
    qa_llm = RetrievalQA.from_chain_type(llm = chat,
                                        chain_type = 'stuff',
                                        retriever = retriever,
                                        return_source_documents = True,
                                        chain_type_kwargs = {'prompt': prompt})
    with get_openai_callback() as cb:
#        print('working {}\n'.format(doc_id))
        output = qa_llm({'query': q})
#        print(output['result'])
        now = datetime.datetime.now(timezone('Asia/Seoul'))
        now = now.strftime("%Y%m%d_%H%M%S")
        openai_cb[now] = cb
    return output

# %%
output_parser = CommaSeparatedListOutputParser()
mats_all_paper = {pdf_id: get_answer(pdf_id, q_mat, output_parser)['result'] for pdf_id in pdf_ids}
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:141: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   warn_deprecated(

# %%
mats_all_paper
# Out:
# {'WZ62GXAT': '{"response": "nano-TiO2 (TiO2)"}',
#  'UK8SV8XM': '{\n  "nanoparticles": "Citrate coated iron oxide (Fe3O4), PEG400DMA coated iron oxide (Fe3O4)"\n}',
#  'JST2FHKJ': 'IONPs (Fe3O4)',
#  'KT5U49ZB': 'Ferumoxtran-10 (Fe3O4)',
#  '95KXTZVR': 'MgNPs-Fe3O4 (Fe3O4)',
#  '8A3RUDZD': 'Fe3O4-PEI-FI-HA6K (Fe3O4), Fe3O4-PEI-FI-HA31K (Fe3O4)',
#  'DUR86VJI': '{\n  "nanoparticles": "Al2O3 (Al2O3), CuO (CuO), CeO2 (CeO2), Co3O4 (Co3O4), CoO (CoO), Cr2O3 (Cr2O3), Fe2O3 (Fe2O3), Fe3O4 (Fe3O4), Gd2O3 (Gd2O3), HfO2 (HfO2), In2O3 (In2O3), Mn2O3 (Mn2O3), Ni2O3 (Ni2O3), NiO (NiO), SiO2 (SiO2), SnO2 (SnO2), TiO2 (TiO2), Y2O3 (Y2O3), Yb2O3 (Yb2O3), ZnO (ZnO), ZrO2 (ZrO2)"\n}',
#  'U5TWM8XC': '{\n  "nanoparticles": "INOPS (Fe2O3), INOPS-PLL (Fe2O3)"\n}',
#  'I3MS5H2K': '{\n  "nanoparticles": "MNP core (Fe3O4), MNP@PEG POSS (Fe3O4), MNP@OctaTMA POSS (Fe3O4)"\n}',
#  '9843ENP3': '{\n  "nanoparticles": "SPIO (Fe3O4), SPIO@SiO2 (Fe3O4), SPIO@SiO2-NH2 (Fe3O4), SPIO@dextran (Fe3O4)"\n}',
#  'W5DHTC2Z': 'SPIO nanocomposites (Fe3O4)'}

# %% [markdown]
# # material data extracted

# %%
# OutputFixingPaser

from langchain.output_parsers import OutputFixingParser
fixing_parser = OutputFixingParser.from_llm(parser = output_parser, llm = chat)

mats_all_paper_fix = {}
for key, value in mats_all_paper.items():
    value_fix = fixing_parser.parse(value)
    mats_all_paper_fix[key] = value_fix

mats_all_paper_fix
# Out:
# {'WZ62GXAT': ['{"response": "nano-TiO2 (TiO2)"}'],
#  'UK8SV8XM': ['{\n  "nanoparticles": "Citrate coated iron oxide (Fe3O4)',
#   'PEG400DMA coated iron oxide (Fe3O4)"\n}'],
#  'JST2FHKJ': ['IONPs (Fe3O4)'],
#  'KT5U49ZB': ['Ferumoxtran-10 (Fe3O4)'],
#  '95KXTZVR': ['MgNPs-Fe3O4 (Fe3O4)'],
#  '8A3RUDZD': ['Fe3O4-PEI-FI-HA6K (Fe3O4)', 'Fe3O4-PEI-FI-HA31K (Fe3O4)'],
#  'DUR86VJI': ['{\n  "nanoparticles": "Al2O3 (Al2O3)',
#   'CuO (CuO)',
#   'CeO2 (CeO2)',
#   'Co3O4 (Co3O4)',
#   'CoO (CoO)',
#   'Cr2O3 (Cr2O3)',
#   'Fe2O3 (Fe2O3)',
#   'Fe3O4 (Fe3O4)',
#   'Gd2O3 (Gd2O3)',
#   'HfO2 (HfO2)',
#   'In2O3 (In2O3)',
#   'Mn2O3 (Mn2O3)',
#   'Ni2O3 (Ni2O3)',
#   'NiO (NiO)',
#   'SiO2 (SiO2)',
#   'SnO2 (SnO2)',
#   'TiO2 (TiO2)',
#   'Y2O3 (Y2O3)',
#   'Yb2O3 (Yb2O3)',
#   'ZnO (ZnO)',
#   'ZrO2 (ZrO2)"\n}'],
#  'U5TWM8XC': ['{\n  "nanoparticles": "INOPS (Fe2O3)', 'INOPS-PLL (Fe2O3)"\n}'],
#  'I3MS5H2K': ['{\n  "nanoparticles": "MNP core (Fe3O4)',
#   'MNP@PEG POSS (Fe3O4)',
#   'MNP@OctaTMA POSS (Fe3O4)"\n}'],
#  '9843ENP3': ['{\n  "nanoparticles": "SPIO (Fe3O4)',
#   'SPIO@SiO2 (Fe3O4)',
#   'SPIO@SiO2-NH2 (Fe3O4)',
#   'SPIO@dextran (Fe3O4)"\n}'],
#  'W5DHTC2Z': ['SPIO nanocomposites (Fe3O4)']}

# %%
# Pchem info. extraction

# %%
from dataclasses import dataclass

@dataclass
class gpt_responses:
    pdf_id: str
    mat_name: str
    pchem_product_info: str
    pchem_mat_synthesis: str
    pchem_core_size: str
    pchem_hydrodynamic_size: str
    pchem_surface_charge: str
    pchem_surface_area: str

# %%
import json
import textwrap
import langchain_core.output_parsers


def get_sub_answers(mat, q, key, data_class):
    schema = data_class.schema()
    field_names = list(schema['properties'].keys())
    field_names.insert(0, 'key')
    #print(field_names)

    output_parser = PydanticOutputParser(pydantic_object=data_class)
    ans = get_answer(key, q, output_parser)

    fixing_parser = OutputFixingParser.from_llm(parser = output_parser, llm = chat)

    text = ans['result']
    py = fixing_parser.parse(text)
    py_dict = py.to_dict()

    #print(py_dict)

    pchem_df = pd.DataFrame.from_records(py_dict, index = ["0"])
    pchem_df.insert(0, 'key', key)
    #pchem_df.insert(0, 'ref', pdf_dict[key])
    print(pchem_df)

    return(pchem_df)

#i = "TiO2 P25–70 nano-TiO2"
#q = "please pull out material information of " + i + " in the document."
#tmp = get_sub_answers(i, q, "95ASP9SZ", pchem_product_info)

# %%
all_pchem_dfs = []
all_gpt_responses = []
error_files = []

for key, value in mats_all_paper_fix.items():
    try:
        # make for loop to print each value
        for i in value:
            print(key + ": " + i)

            q = "please pull out material information of " + i + " in the document."
            pchem_df = get_sub_answers(i, q, key, pchem_product_info)

            q = "please pull out material synthesis information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_mat_synthesis)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')

            q = "please pull out core size information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_core_size)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')

            q = "please pull out hydrodynamic size information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_hydrodynamic_size)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')

            q = "please pull out surface charge information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_surface_charge)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')

            q = "please pull out surface area information of " + i + " in the document."
            pchem_df_add = get_sub_answers(i, q, key, pchem_surface_area)
            pchem_df = pd.merge(pchem_df, pchem_df_add, on='key')
            pchem_df.insert(0, 'ref', pdf_dict[key])

            # Append pchem_df to the list
            all_pchem_dfs.append(pchem_df)

    except Exception as e:
        # 오류가 발생한 파일을 기록하고, 다음 파일로 넘어감
        print(f"Error processing {key}: {e}")
        error_files.append(key)

# Combine all pchem_df DataFrames into a single DataFrame
all_pchem_df = pd.concat(all_pchem_dfs, ignore_index=True)
all_pchem_df['ref'] = all_pchem_df['key'].map(lambda x: pdf_dict[x] if x in pdf_dict else None)
# Out:
# WZ62GXAT: {"response": "nano-TiO2 (TiO2)"}
#         key          mat_name
# 0  WZ62GXAT  nano-TiO2 (TiO2)
#         key           mat_synthesis
# 0  WZ62GXAT  Commercially available
#         key mat_core_size
# 0  WZ62GXAT         20-50
#         key mat_hydrodynamic_size
# 0  WZ62GXAT                 368.1
#         key mat_surface_charge
# 0  WZ62GXAT               None
#         key mat_surface_area
# 0  WZ62GXAT             None
# UK8SV8XM: {
#   "nanoparticles": "Citrate coated iron oxide (Fe3O4)
#         key                           mat_name
# 0  UK8SV8XM  Citrate coated iron oxide (Fe3O4)
#         key mat_synthesis
# 0  UK8SV8XM   Synthesized
#         key mat_core_size
# 0  UK8SV8XM            10
#         key mat_hydrodynamic_size
# 0  UK8SV8XM                    62
#         key mat_surface_charge
# 0  UK8SV8XM               None
#         key mat_surface_area
# 0  UK8SV8XM             None
# UK8SV8XM: PEG400DMA coated iron oxide (Fe3O4)"
# }
#         key                             mat_name
# 0  UK8SV8XM  PEG400DMA coated iron oxide (Fe3O4)
#         key mat_synthesis
# 0  UK8SV8XM   Synthesized
#         key mat_core_size
# 0  UK8SV8XM          None
#         key mat_hydrodynamic_size
# 0  UK8SV8XM                   198
#         key mat_surface_charge
# 0  UK8SV8XM               None
#         key mat_surface_area
# 0  UK8SV8XM             None
# JST2FHKJ: IONPs (Fe3O4)
#         key       mat_name
# 0  JST2FHKJ  IONPs (Fe3O4)
#         key mat_synthesis
# 0  JST2FHKJ   Synthesized
#         key mat_core_size
# 0  JST2FHKJ           7-9
#         key mat_hydrodynamic_size
# 0  JST2FHKJ                    86
#         key                     mat_surface_charge
# 0  JST2FHKJ  40 (pH: 2); -25 (pH: 10); 0 (pH: 6.8)
#         key mat_surface_area
# 0  JST2FHKJ             None
# KT5U49ZB: Ferumoxtran-10 (Fe3O4)
#         key                mat_name
# 0  KT5U49ZB  Ferumoxtran-10 (Fe3O4)
#         key                                      mat_synthesis
# 0  KT5U49ZB  Commercially available (Sinerem®, Guerbet, Fra...
#         key mat_core_size
# 0  KT5U49ZB             5
#         key mat_hydrodynamic_size
# 0  KT5U49ZB                  None
#         key mat_surface_charge
# 0  KT5U49ZB               None
#         key mat_surface_area
# 0  KT5U49ZB             None
# 95KXTZVR: MgNPs-Fe3O4 (Fe3O4)
#         key             mat_name
# 0  95KXTZVR  MgNPs-Fe3O4 (Fe3O4)
#         key           mat_synthesis
# 0  95KXTZVR  Commercially available
#         key mat_core_size
# 0  95KXTZVR            10
#         key                              mat_hydrodynamic_size
# 0  95KXTZVR  60-100 (Solvent: suspension); 100-120 (Concent...
#         key mat_surface_charge
# 0  95KXTZVR   -30--40 (pH: 10)
#         key mat_surface_area
# 0  95KXTZVR          100-120
# 8A3RUDZD: Fe3O4-PEI-FI-HA6K (Fe3O4)
#         key                   mat_name
# 0  8A3RUDZD  Fe3O4-PEI-FI-HA6K (Fe3O4)
#         key mat_synthesis
# 0  8A3RUDZD   Synthesized
#         key mat_core_size
# 0  8A3RUDZD      15.6±3.4
#         key   mat_hydrodynamic_size
# 0  8A3RUDZD  190.5 (Solvent: water)
#         key mat_surface_charge
# 0  8A3RUDZD               16.3
#         key mat_surface_area
# 0  8A3RUDZD             None
# 8A3RUDZD: Fe3O4-PEI-FI-HA31K (Fe3O4)
#         key                    mat_name
# 0  8A3RUDZD  Fe3O4-PEI-FI-HA31K (Fe3O4)
#         key mat_synthesis
# 0  8A3RUDZD   Synthesized
#         key mat_core_size
# 0  8A3RUDZD      16.1±2.9
#         key mat_hydrodynamic_size
# 0  8A3RUDZD                 217.1
#         key mat_surface_charge
# 0  8A3RUDZD               21.9
#         key mat_surface_area
# 0  8A3RUDZD             None
# DUR86VJI: {
#   "nanoparticles": "Al2O3 (Al2O3)
#         key       mat_name
# 0  DUR86VJI  Al2O3 (Al2O3)
#         key                              mat_synthesis
# 0  DUR86VJI  Commercially available (Al2O3 NPs, 10 nm)
#         key mat_core_size
# 0  DUR86VJI      14.7±5.2
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  260.4±16.9 (Solvent: BEGM); 230.5±6.6 (Solvent...
#         key mat_surface_charge
# 0  DUR86VJI     7.4 (pH: PZZP)
#         key mat_surface_area
# 0  DUR86VJI             None
# DUR86VJI: CuO (CuO)
#         key   mat_name
# 0  DUR86VJI  CuO (CuO)
#         key mat_synthesis
# 0  DUR86VJI   Synthesized
#         key mat_core_size
# 0  DUR86VJI      12.8±3.4
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  305.3±5.6 (Solvent: BEGM); 313.8±4.9 (Solvent:...
#         key mat_surface_charge
# 0  DUR86VJI                7.9
#         key mat_surface_area
# 0  DUR86VJI             None
# DUR86VJI: CeO2 (CeO2)
#         key     mat_name
# 0  DUR86VJI  CeO2 (CeO2)
#         key                            mat_synthesis
# 0  DUR86VJI  Commercially available (CeO2 NPs, 8 nm)
#         key mat_core_size
# 0  DUR86VJI      18.3±6.8
#         key mat_hydrodynamic_size
# 0  DUR86VJI                  None
#         key                                 mat_surface_charge
# 0  DUR86VJI  197.6±7.0 (Solvent: water); 261.6±7.3 (Solvent...
#         key mat_surface_area
# 0  DUR86VJI             None
# DUR86VJI: Co3O4 (Co3O4)
#         key       mat_name
# 0  DUR86VJI  Co3O4 (Co3O4)
#         key mat_synthesis
# 0  DUR86VJI   Synthesized
#         key mat_core_size
# 0  DUR86VJI      10.0±2.4
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  222.7±4.4 (Solvent: BEGM); 230.3±4.5 (Solvent:...
#         key mat_surface_charge
# 0  DUR86VJI         9.4 (PZZP)
#         key mat_surface_area
# 0  DUR86VJI        174.5±4.1
# DUR86VJI: CoO (CoO)
#         key   mat_name
# 0  DUR86VJI  CoO (CoO)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (2310SC)
#         key mat_core_size
# 0  DUR86VJI     71.8±16.2
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  208.3±5.4 (Solvent: BEGM); 191.6±7.1 (Solvent:...
#         key                                 mat_surface_charge
# 0  DUR86VJI  184.8±11.4 (Time: 0 h); 208.3±5.4 (Time: 24 h)...
#         key mat_surface_area
# 0  DUR86VJI        71.8±16.2
# DUR86VJI: Cr2O3 (Cr2O3)
#         key       mat_name
# 0  DUR86VJI  Cr2O3 (Cr2O3)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (US3060)
#         key mat_core_size
# 0  DUR86VJI    193.0±90.0
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  316.9±5.6 (Solvent: BEGM); 318.7±7.9 (Solvent:...
#         key mat_surface_charge
# 0  DUR86VJI               None
#         key mat_surface_area
# 0  DUR86VJI       193.0±90.0
# DUR86VJI: Fe2O3 (Fe2O3)
#         key       mat_name
# 0  DUR86VJI  Fe2O3 (Fe2O3)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (US3200)
#         key mat_core_size
# 0  DUR86VJI      12.3±2.9
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  206.3±6.8 (Solvent: BEGM); 196.6±4.3 (Solvent:...
#         key mat_surface_charge
# 0  DUR86VJI           12.3±2.9
#         key mat_surface_area
# 0  DUR86VJI         12.3±2.9
# DUR86VJI: Fe3O4 (Fe3O4)
#         key       mat_name
# 0  DUR86VJI  Fe3O4 (Fe3O4)
#         key mat_synthesis
# 0  DUR86VJI   Synthesized
#         key mat_core_size
# 0  DUR86VJI      12.0±3.2
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  256.6±9.3 (Solvent: BEGM); 243.6±5.3 (Solvent:...
#         key     mat_surface_charge
# 0  DUR86VJI  5.78 (Solvent: water)
#         key mat_surface_area
# 0  DUR86VJI        198.4±4.1
# DUR86VJI: Gd2O3 (Gd2O3)
#         key       mat_name
# 0  DUR86VJI  Gd2O3 (Gd2O3)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (2681RE)
#         key mat_core_size
# 0  DUR86VJI     43.8±15.8
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  227.4±4.6 (Solvent: BEGM); 222.0±4.9 (Solvent:...
#         key mat_surface_charge
# 0  DUR86VJI          43.8±15.8
#         key mat_surface_area
# 0  DUR86VJI        43.8±15.8
# DUR86VJI: HfO2 (HfO2)
#         key     mat_name
# 0  DUR86VJI  HfO2 (HfO2)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (US3245)
#         key mat_core_size
# 0  DUR86VJI      28.4±7.3
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  307.7±4.3 (Solvent: BEGM); 280.6±1.6 (Solvent:...
#         key mat_surface_charge
# 0  DUR86VJI                8.1
#         key mat_surface_area
# 0  DUR86VJI         28.4±7.3
# DUR86VJI: In2O3 (In2O3)
#         key       mat_name
# 0  DUR86VJI  In2O3 (In2O3)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (US3250)
#         key mat_core_size
# 0  DUR86VJI     59.6±19.0
#         key                         mat_hydrodynamic_size
# 0  DUR86VJI  259.8 (Solvent: BEGM); 244.5 (Solvent: DMEM)
#         key                                 mat_surface_charge
# 0  DUR86VJI  192.2±2.1 (Solvent: medium); 259.8±1.2 (Time: ...
#         key mat_surface_area
# 0  DUR86VJI        59.6±19.0
# DUR86VJI: Mn2O3 (Mn2O3)
#         key       mat_name
# 0  DUR86VJI  Mn2O3 (Mn2O3)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (3610FY)
#         key mat_core_size
# 0  DUR86VJI          None
#         key                         mat_hydrodynamic_size
# 0  DUR86VJI  298.4 (Solvent: BEGM); 291.7 (Solvent: DMEM)
#         key                                 mat_surface_charge
# 0  DUR86VJI  51.5±7.3 (Solvent: water); 286.8±2.8 (Solvent:...
#         key mat_surface_area
# 0  DUR86VJI         51.5±7.3
# DUR86VJI: Ni2O3 (Ni2O3)
#         key       mat_name
# 0  DUR86VJI  Ni2O3 (Ni2O3)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (5420SC)
#         key mat_core_size
# 0  DUR86VJI    140.6±52.5
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  339.5±9.9 (Solvent: BEGM); 322.6±13.6 (Solvent...
#         key                                 mat_surface_charge
# 0  DUR86VJI  140.6±52.5 (Solvent: water); 311.4±7.1 (Time: ...
#         key mat_surface_area
# 0  DUR86VJI       140.6±52.5
# DUR86VJI: NiO (NiO)
#         key   mat_name
# 0  DUR86VJI  NiO (NiO)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (637130)
#         key mat_core_size
# 0  DUR86VJI        10-100
#         key      mat_hydrodynamic_size
# 0  DUR86VJI  313.8±4.9 (Solvent: DMEM)
#         key mat_surface_charge
# 0  DUR86VJI               11.4
#         key mat_surface_area
# 0  DUR86VJI         13.1±5.9
# DUR86VJI: SiO2 (SiO2)
#         key     mat_name
# 0  DUR86VJI  SiO2 (SiO2)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (4850MR)
#         key mat_core_size
# 0  DUR86VJI          None
#         key mat_hydrodynamic_size
# 0  DUR86VJI                  None
#         key mat_surface_charge
# 0  DUR86VJI                  1
#         key mat_surface_area
# 0  DUR86VJI        113.4±4.2
# DUR86VJI: SnO2 (SnO2)
#         key     mat_name
# 0  DUR86VJI  SnO2 (SnO2)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (US3460)
#         key mat_core_size
# 0  DUR86VJI     62.4±13.2
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  203.7±4.7 (Solvent: water); 242.5±5.0 (Solvent...
#         key                                 mat_surface_charge
# 0  DUR86VJI  62.4±13.2 (Solvent: water); 203.7±4.7 (Solvent...
#         key mat_surface_area
# 0  DUR86VJI        62.4±13.2
# DUR86VJI: TiO2 (TiO2)
#         key     mat_name
# 0  DUR86VJI  TiO2 (TiO2)
#         key mat_synthesis
# 0  DUR86VJI   Synthesized
#         key mat_core_size
# 0  DUR86VJI      12.6±4.3
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  109.2±8.8 (Solvent: BEGM); 55.9±1.2 (Solvent: ...
#         key mat_surface_charge
# 0  DUR86VJI                6.4
#         key mat_surface_area
# 0  DUR86VJI        166.0±6.3
# DUR86VJI: Y2O3 (Y2O3)
#         key     mat_name
# 0  DUR86VJI  Y2O3 (Y2O3)
#         key                              mat_synthesis
# 0  DUR86VJI  Commercially available (Y2O3 NPs, 810 nm)
#         key mat_core_size
# 0  DUR86VJI      32.7±8.1
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  332.2±9.0 (Solvent: BEGM); 351.6±8.9 (Solvent:...
#         key                                 mat_surface_charge
# 0  DUR86VJI  32.7±8.1 (Time: 0 h); 312.2±15.4 (Time: 24 h);...
#         key mat_surface_area
# 0  DUR86VJI              9.6
# DUR86VJI: Yb2O3 (Yb2O3)
#         key       mat_name
# 0  DUR86VJI  Yb2O3 (Yb2O3)
#         key                           mat_synthesis
# 0  DUR86VJI  Commercially available (MKN-Yb2O3-090)
#         key mat_core_size
# 0  DUR86VJI     61.7±11.3
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  230.7±1.8 (Solvent: water); 296.1±5.7 (Solvent...
#         key mat_surface_charge
# 0  DUR86VJI                8.2
#         key mat_surface_area
# 0  DUR86VJI              5.1
# DUR86VJI: ZnO (ZnO)
#         key   mat_name
# 0  DUR86VJI  ZnO (ZnO)
#         key mat_synthesis
# 0  DUR86VJI   Synthesized
#         key mat_core_size
# 0  DUR86VJI      22.6±5.1
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  114.7±10.5 (Solvent: BEGM); 69.4±0.4 (Solvent:...
#         key mat_surface_charge
# 0  DUR86VJI      9.6 (pH: 9.6)
#         key mat_surface_area
# 0  DUR86VJI             None
# DUR86VJI: ZrO2 (ZrO2)"
# }
#         key     mat_name
# 0  DUR86VJI  ZrO2 (ZrO2)
#         key                    mat_synthesis
# 0  DUR86VJI  Commercially available (US3600)
#         key mat_core_size
# 0  DUR86VJI     40.1±12.6
#         key                              mat_hydrodynamic_size
# 0  DUR86VJI  314.3±9.9 (Solvent: BEGM); 312.3±10.2 (Solvent...
#         key mat_surface_charge
# 0  DUR86VJI                5.8
#         key mat_surface_area
# 0  DUR86VJI             5.62
# U5TWM8XC: {
#   "nanoparticles": "INOPS (Fe2O3)
#         key       mat_name
# 0  U5TWM8XC  INOPS (Fe2O3)
#         key mat_synthesis
# 0  U5TWM8XC   Synthesized
#         key mat_core_size
# 0  U5TWM8XC        80-150
#         key mat_hydrodynamic_size
# 0  U5TWM8XC                80-150
#         key mat_surface_charge
# 0  U5TWM8XC               None
#         key mat_surface_area
# 0  U5TWM8XC             None
# U5TWM8XC: INOPS-PLL (Fe2O3)"
# }
#         key           mat_name
# 0  U5TWM8XC  INOPS-PLL (Fe2O3)
#         key mat_synthesis
# 0  U5TWM8XC   Synthesized
#         key mat_core_size
# 0  U5TWM8XC        80-150
#         key mat_hydrodynamic_size
# 0  U5TWM8XC                80-150
#         key mat_surface_charge
# 0  U5TWM8XC               None
#         key mat_surface_area
# 0  U5TWM8XC             None
# I3MS5H2K: {
#   "nanoparticles": "MNP core (Fe3O4)
#         key          mat_name
# 0  I3MS5H2K  MNP core (Fe3O4)
#         key mat_synthesis
# 0  I3MS5H2K   Synthesized
#         key mat_core_size
# 0  I3MS5H2K          50.7
#         key mat_hydrodynamic_size
# 0  I3MS5H2K                  None
#         key mat_surface_charge
# 0  I3MS5H2K               None
#         key mat_surface_area
# 0  I3MS5H2K             None
# I3MS5H2K: MNP@PEG POSS (Fe3O4)
#         key              mat_name
# 0  I3MS5H2K  MNP@PEG POSS (Fe3O4)
#         key mat_synthesis
# 0  I3MS5H2K   Synthesized
#         key mat_core_size
# 0  I3MS5H2K          60.3
#         key mat_hydrodynamic_size
# 0  I3MS5H2K                  60.3
#         key mat_surface_charge
# 0  I3MS5H2K               None
#         key mat_surface_area
# 0  I3MS5H2K            55.24
# I3MS5H2K: MNP@OctaTMA POSS (Fe3O4)"
# }
#         key                  mat_name
# 0  I3MS5H2K  MNP@OctaTMA POSS (Fe3O4)
#         key mat_synthesis
# 0  I3MS5H2K   Synthesized
#         key mat_core_size
# 0  I3MS5H2K          60.7
#         key mat_hydrodynamic_size
# 0  I3MS5H2K                  60.7
#         key mat_surface_charge
# 0  I3MS5H2K               None
#         key mat_surface_area
# 0  I3MS5H2K           131.30
# 9843ENP3: {
#   "nanoparticles": "SPIO (Fe3O4)
#         key      mat_name
# 0  9843ENP3  SPIO (Fe3O4)
#         key mat_synthesis
# 0  9843ENP3   Synthesized
#         key mat_core_size
# 0  9843ENP3             7
#         key mat_hydrodynamic_size
# 0  9843ENP3                  None
#         key mat_surface_charge
# 0  9843ENP3               None
#         key mat_surface_area
# 0  9843ENP3             None
# 9843ENP3: SPIO@SiO2 (Fe3O4)
#         key           mat_name
# 0  9843ENP3  SPIO@SiO2 (Fe3O4)
#         key mat_synthesis
# 0  9843ENP3   Synthesized
#         key mat_core_size
# 0  9843ENP3             7
#         key mat_hydrodynamic_size
# 0  9843ENP3                    15
#         key  mat_surface_charge
# 0  9843ENP3  Negative (pH: 7.4)
#         key mat_surface_area
# 0  9843ENP3             None
# 9843ENP3: SPIO@SiO2-NH2 (Fe3O4)
#         key               mat_name
# 0  9843ENP3  SPIO@SiO2-NH2 (Fe3O4)
#         key mat_synthesis
# 0  9843ENP3   Synthesized
#         key mat_core_size
# 0  9843ENP3             7
#         key mat_hydrodynamic_size
# 0  9843ENP3                    15
#         key  mat_surface_charge
# 0  9843ENP3  Positive (pH: 7.4)
#         key mat_surface_area
# 0  9843ENP3             None
# 9843ENP3: SPIO@dextran (Fe3O4)"
# }
#         key              mat_name
# 0  9843ENP3  SPIO@dextran (Fe3O4)
#         key mat_synthesis
# 0  9843ENP3   Synthesized
#         key mat_core_size
# 0  9843ENP3             7
#         key mat_hydrodynamic_size
# 0  9843ENP3                  None
#         key  mat_surface_charge
# 0  9843ENP3  -6.9±5.6 (pH: 7.4)
#         key mat_surface_area
# 0  9843ENP3             None
# W5DHTC2Z: SPIO nanocomposites (Fe3O4)
#         key                     mat_name
# 0  W5DHTC2Z  SPIO nanocomposites (Fe3O4)
#         key mat_synthesis
# 0  W5DHTC2Z   Synthesized
#         key mat_core_size
# 0  W5DHTC2Z       8.4±2.3
#         key mat_hydrodynamic_size
# 0  W5DHTC2Z                    97
#         key mat_surface_charge
# 0  W5DHTC2Z           28.4±5.7
#         key mat_surface_area
# 0  W5DHTC2Z             None

# %%
# 오류가 발생한 파일 출력
if error_files:
    print("The following files encountered errors:")
    for error_file in error_files:
        print(error_file)
else:
    print("No errors encountered.")
# Out:
# No errors encountered.

# %% [markdown]
# # Pchem data extraction result

# %%
all_pchem_df
# Out:
#              ref       key                             mat_name  \
# 0       19922763  WZ62GXAT                     nano-TiO2 (TiO2)
# 1   24094173.pdf  UK8SV8XM    Citrate coated iron oxide (Fe3O4)
# 2   24094173.pdf  UK8SV8XM  PEG400DMA coated iron oxide (Fe3O4)
# 3   24788586.pdf  JST2FHKJ                        IONPs (Fe3O4)
# 4   17178155.pdf  KT5U49ZB               Ferumoxtran-10 (Fe3O4)
# 5   23892599.pdf  95KXTZVR                  MgNPs-Fe3O4 (Fe3O4)
# 6   24462358.pdf  8A3RUDZD            Fe3O4-PEI-FI-HA6K (Fe3O4)
# 7   24462358.pdf  8A3RUDZD           Fe3O4-PEI-FI-HA31K (Fe3O4)
# 8   22502734.pdf  DUR86VJI                        Al2O3 (Al2O3)
# 9   22502734.pdf  DUR86VJI                            CuO (CuO)
# 10  22502734.pdf  DUR86VJI                          CeO2 (CeO2)
# 11  22502734.pdf  DUR86VJI                        Co3O4 (Co3O4)
# 12  22502734.pdf  DUR86VJI                            CoO (CoO)
# 13  22502734.pdf  DUR86VJI                        Cr2O3 (Cr2O3)
# 14  22502734.pdf  DUR86VJI                        Fe2O3 (Fe2O3)
# 15  22502734.pdf  DUR86VJI                        Fe3O4 (Fe3O4)
# 16  22502734.pdf  DUR86VJI                        Gd2O3 (Gd2O3)
# 17  22502734.pdf  DUR86VJI                          HfO2 (HfO2)
# 18  22502734.pdf  DUR86VJI                        In2O3 (In2O3)
# 19  22502734.pdf  DUR86VJI                        Mn2O3 (Mn2O3)
# 20  22502734.pdf  DUR86VJI                        Ni2O3 (Ni2O3)
# 21  22502734.pdf  DUR86VJI                            NiO (NiO)
# 22  22502734.pdf  DUR86VJI                          SiO2 (SiO2)
# 23  22502734.pdf  DUR86VJI                          SnO2 (SnO2)
# 24  22502734.pdf  DUR86VJI                          TiO2 (TiO2)
# 25  22502734.pdf  DUR86VJI                          Y2O3 (Y2O3)
# 26  22502734.pdf  DUR86VJI                        Yb2O3 (Yb2O3)
# 27  22502734.pdf  DUR86VJI                            ZnO (ZnO)
# 28  22502734.pdf  DUR86VJI                          ZrO2 (ZrO2)
# 29  22776829.pdf  U5TWM8XC                        INOPS (Fe2O3)
# 30  22776829.pdf  U5TWM8XC                    INOPS-PLL (Fe2O3)
# 31  25630810.pdf  I3MS5H2K                     MNP core (Fe3O4)
# 32  25630810.pdf  I3MS5H2K                 MNP@PEG POSS (Fe3O4)
# 33  25630810.pdf  I3MS5H2K             MNP@OctaTMA POSS (Fe3O4)
# 34  22393292.pdf  9843ENP3                         SPIO (Fe3O4)
# 35  22393292.pdf  9843ENP3                    SPIO@SiO2 (Fe3O4)
# 36  22393292.pdf  9843ENP3                SPIO@SiO2-NH2 (Fe3O4)
# 37  22393292.pdf  9843ENP3                 SPIO@dextran (Fe3O4)
# 38  26773667.pdf  W5DHTC2Z          SPIO nanocomposites (Fe3O4)
#
#                                         mat_synthesis mat_core_size  \
# 0                              Commercially available         20-50
# 1                                         Synthesized            10
# 2                                         Synthesized          None
# 3                                         Synthesized           7-9
# 4   Commercially available (Sinerem®, Guerbet, Fra...             5
# 5                              Commercially available            10
# 6                                         Synthesized      15.6±3.4
# 7                                         Synthesized      16.1±2.9
# 8           Commercially available (Al2O3 NPs, 10 nm)      14.7±5.2
# 9                                         Synthesized      12.8±3.4
# 10            Commercially available (CeO2 NPs, 8 nm)      18.3±6.8
# 11                                        Synthesized      10.0±2.4
# 12                    Commercially available (2310SC)     71.8±16.2
# 13                    Commercially available (US3060)    193.0±90.0
# 14                    Commercially available (US3200)      12.3±2.9
# 15                                        Synthesized      12.0±3.2
# 16                    Commercially available (2681RE)     43.8±15.8
# 17                    Commercially available (US3245)      28.4±7.3
# 18                    Commercially available (US3250)     59.6±19.0
# 19                    Commercially available (3610FY)          None
# 20                    Commercially available (5420SC)    140.6±52.5
# 21                    Commercially available (637130)        10-100
# 22                    Commercially available (4850MR)          None
# 23                    Commercially available (US3460)     62.4±13.2
# 24                                        Synthesized      12.6±4.3
# 25          Commercially available (Y2O3 NPs, 810 nm)      32.7±8.1
# 26             Commercially available (MKN-Yb2O3-090)     61.7±11.3
# 27                                        Synthesized      22.6±5.1
# 28                    Commercially available (US3600)     40.1±12.6
# 29                                        Synthesized        80-150
# 30                                        Synthesized        80-150
# 31                                        Synthesized          50.7
# 32                                        Synthesized          60.3
# 33                                        Synthesized          60.7
# 34                                        Synthesized             7
# 35                                        Synthesized             7
# 36                                        Synthesized             7
# 37                                        Synthesized             7
# 38                                        Synthesized       8.4±2.3
#
#                                 mat_hydrodynamic_size  \
# 0                                               368.1
# 1                                                  62
# 2                                                 198
# 3                                                  86
# 4                                                None
# 5   60-100 (Solvent: suspension); 100-120 (Concent...
# 6                              190.5 (Solvent: water)
# 7                                               217.1
# 8   260.4±16.9 (Solvent: BEGM); 230.5±6.6 (Solvent...
# 9   305.3±5.6 (Solvent: BEGM); 313.8±4.9 (Solvent:...
# 10                                               None
# 11  222.7±4.4 (Solvent: BEGM); 230.3±4.5 (Solvent:...
# 12  208.3±5.4 (Solvent: BEGM); 191.6±7.1 (Solvent:...
# 13  316.9±5.6 (Solvent: BEGM); 318.7±7.9 (Solvent:...
# 14  206.3±6.8 (Solvent: BEGM); 196.6±4.3 (Solvent:...
# 15  256.6±9.3 (Solvent: BEGM); 243.6±5.3 (Solvent:...
# 16  227.4±4.6 (Solvent: BEGM); 222.0±4.9 (Solvent:...
# 17  307.7±4.3 (Solvent: BEGM); 280.6±1.6 (Solvent:...
# 18       259.8 (Solvent: BEGM); 244.5 (Solvent: DMEM)
# 19       298.4 (Solvent: BEGM); 291.7 (Solvent: DMEM)
# 20  339.5±9.9 (Solvent: BEGM); 322.6±13.6 (Solvent...
# 21                          313.8±4.9 (Solvent: DMEM)
# 22                                               None
# 23  203.7±4.7 (Solvent: water); 242.5±5.0 (Solvent...
# 24  109.2±8.8 (Solvent: BEGM); 55.9±1.2 (Solvent: ...
# 25  332.2±9.0 (Solvent: BEGM); 351.6±8.9 (Solvent:...
# 26  230.7±1.8 (Solvent: water); 296.1±5.7 (Solvent...
# 27  114.7±10.5 (Solvent: BEGM); 69.4±0.4 (Solvent:...
# 28  314.3±9.9 (Solvent: BEGM); 312.3±10.2 (Solvent...
# 29                                             80-150
# 30                                             80-150
# 31                                               None
# 32                                               60.3
# 33                                               60.7
# 34                                               None
# 35                                                 15
# 36                                                 15
# 37                                               None
# 38                                                 97
#
#                                    mat_surface_charge mat_surface_area
# 0                                                None             None
# 1                                                None             None
# 2                                                None             None
# 3               40 (pH: 2); -25 (pH: 10); 0 (pH: 6.8)             None
# 4                                                None             None
# 5                                    -30--40 (pH: 10)          100-120
# 6                                                16.3             None
# 7                                                21.9             None
# 8                                      7.4 (pH: PZZP)             None
# 9                                                 7.9             None
# 10  197.6±7.0 (Solvent: water); 261.6±7.3 (Solvent...             None
# 11                                         9.4 (PZZP)        174.5±4.1
# 12  184.8±11.4 (Time: 0 h); 208.3±5.4 (Time: 24 h)...        71.8±16.2
# 13                                               None       193.0±90.0
# 14                                           12.3±2.9         12.3±2.9
# 15                              5.78 (Solvent: water)        198.4±4.1
# 16                                          43.8±15.8        43.8±15.8
# 17                                                8.1         28.4±7.3
# 18  192.2±2.1 (Solvent: medium); 259.8±1.2 (Time: ...        59.6±19.0
# 19  51.5±7.3 (Solvent: water); 286.8±2.8 (Solvent:...         51.5±7.3
# 20  140.6±52.5 (Solvent: water); 311.4±7.1 (Time: ...       140.6±52.5
# 21                                               11.4         13.1±5.9
# 22                                                  1        113.4±4.2
# 23  62.4±13.2 (Solvent: water); 203.7±4.7 (Solvent...        62.4±13.2
# 24                                                6.4        166.0±6.3
# 25  32.7±8.1 (Time: 0 h); 312.2±15.4 (Time: 24 h);...              9.6
# 26                                                8.2              5.1
# 27                                      9.6 (pH: 9.6)             None
# 28                                                5.8             5.62
# 29                                               None             None
# 30                                               None             None
# 31                                               None             None
# 32                                               None            55.24
# 33                                               None           131.30
# 34                                               None             None
# 35                                 Negative (pH: 7.4)             None
# 36                                 Positive (pH: 7.4)             None
# 37                                 -6.9±5.6 (pH: 7.4)             None
# 38                                           28.4±5.7             None

# %% [markdown]
# # save extracted Pchem data

# %%
import datetime
from pytz import timezone

now = datetime.datetime.now(timezone('Asia/Seoul'))
now = now.strftime("%Y%m%d_%H%M%S")
o = os.path.join(output_folder, "pchem_gtp_output_" + now + ".xlsx")
all_pchem_df.to_excel(o)
print(o + "로 저장되었습니다.")
# Out:
# output_HEY20241019-Eunyong Ha-Claude 3.5 sonnet-Ha1/pchem_gtp_output_20241020_005245.xlsx로 저장되었습니다.

# %% [markdown]
# # Tox data extraction

# %%
all_tox_dfs = []
all_gpt_responses = []

for key, value in mats_all_paper_fix.items():

    # make for loop to print each value
    for i in value:
        print(key)

        q = "please pull out cytotoxicity information in the document."
        tox_df = get_sub_answers(i, q, key, tox_info)

        #gpt_res = gpt_responses(key, i, ans_info, ans_core, ans_hydro, ans_s_charge, ans_s_area)
        #all_gpt_responses.append(gpt_res)

        # Append pchem_df to the list
        all_tox_dfs.append(tox_df)

# Combine all pchem_df DataFrames into a single DataFrame
all_tox_df = pd.concat(all_tox_dfs, ignore_index=True)
all_tox_df['ref'] = all_tox_df['key'].map(lambda x: pdf_dict[x] if x in pdf_dict else None)
# Out:
# WZ62GXAT
#         key cell_assay cell_classification     cell_organ cell_species  \
# 0  WZ62GXAT        MTT              Cancer  Adrenal gland          Rat
#
#   cell_type
# 0      PC12
# UK8SV8XM
#         key                 cell_assay cell_classification  \
# 0  UK8SV8XM  Live/Dead Viability Assay      Normal; Cancer
#
#                           cell_organ                   cell_species  \
# 0  Fibroblast (NIH 3T3); Lung (A549)  Mouse (NIH 3T3); Human (A549)
#
#        cell_type
# 0  NIH 3T3; A549
# UK8SV8XM
#         key                 cell_assay cell_classification  \
# 0  UK8SV8XM  Live/Dead Viability Assay      Normal; Cancer
#
#                           cell_organ                   cell_species  \
# 0  Fibroblast (NIH 3T3); Lung (A549)  Mouse (NIH 3T3); Human (A549)
#
#        cell_type
# 0  NIH 3T3; A549
# JST2FHKJ
#         key cell_assay cell_classification  cell_organ cell_species cell_type
# 0  JST2FHKJ   MTT; LDH              Normal  Fibroblast        Mouse   NIH 3T3
# KT5U49ZB
#         key        cell_assay cell_classification           cell_organ  \
# 0  KT5U49ZB  Neutral Red; MTT              Normal  Monocyte-macrophage
#
#   cell_species cell_type
# 0        Human       HMM
# 95KXTZVR
#         key cell_assay cell_classification cell_organ cell_species cell_type
# 0  95KXTZVR        LDH              Cancer       Lung        Human      A549
# 8A3RUDZD
#         key cell_assay cell_classification                    cell_organ  \
# 0  8A3RUDZD        MTT              Cancer  Brain (U87MG); Cervix (Hela)
#
#   cell_species    cell_type
# 0        Human  U87MG; Hela
# 8A3RUDZD
#         key cell_assay cell_classification                    cell_organ  \
# 0  8A3RUDZD        MTT              Cancer  Brain (U87MG); Cervix (Hela)
#
#   cell_species    cell_type
# 0        Human  U87MG; Hela
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# DUR86VJI
#         key     cell_assay cell_classification  \
# 0  DUR86VJI  MTS; ATP; LDH              Normal
#
#                                       cell_organ  \
# 0  Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
#
#                          cell_species           cell_type
# 0  Human (BEAS-2B); Mouse (RAW 264.7)  BEAS-2B; RAW 264.7
# U5TWM8XC
#         key   cell_assay cell_classification   cell_organ cell_species  \
# 0  U5TWM8XC  Trypan blue              Cancer  Endothelial        Human
#
#   cell_type
# 0   ECV-304
# U5TWM8XC
#         key   cell_assay cell_classification   cell_organ cell_species  \
# 0  U5TWM8XC  Trypan blue              Cancer  Endothelial        Human
#
#   cell_type
# 0   ECV-304
# I3MS5H2K
#         key      cell_assay cell_classification cell_organ cell_species  \
# 0  I3MS5H2K  CellTiter-Blue              Cancer     Breast        Human
#
#   cell_type
# 0     MCF-7
# I3MS5H2K
#         key      cell_assay cell_classification cell_organ cell_species  \
# 0  I3MS5H2K  CellTiter-Blue              Cancer     Breast        Human
#
#   cell_type
# 0     MCF-7
# I3MS5H2K
#         key      cell_assay cell_classification cell_organ cell_species  \
# 0  I3MS5H2K  CellTiter-Blue              Cancer     Breast        Human
#
#   cell_type
# 0     MCF-7
# 9843ENP3
#         key cell_assay cell_classification  cell_organ cell_species  cell_type
# 0  9843ENP3        MTT              Normal  Macrophage        Mouse  RAW 264.7
# 9843ENP3
#         key cell_assay cell_classification  cell_organ cell_species  cell_type
# 0  9843ENP3        MTT              Normal  Macrophage        Mouse  RAW 264.7
# 9843ENP3
#         key cell_assay cell_classification  cell_organ cell_species  cell_type
# 0  9843ENP3        MTT              Normal  Macrophage        Mouse  RAW 264.7
# 9843ENP3
#         key cell_assay cell_classification  cell_organ cell_species  cell_type
# 0  9843ENP3        MTT              Normal  Macrophage        Mouse  RAW 264.7
# W5DHTC2Z
#         key cell_assay cell_classification  \
# 0  W5DHTC2Z       None              Cancer
#
#                                           cell_organ  \
# 0  Neuroblastoma (N2a); Liver (QGY-7703; HepG2; Q...
#
#                                         cell_species  \
# 0  Mouse (N2a; RAW264.7; NIH3T3); Human (QGY-7703...
#
#                                            cell_type
# 0  N2a; QGY-7703; HepG2; RAW264.7; NIH3T3; QSG-77...

# %%
all_tox_df
# Out:
#          key                 cell_assay cell_classification  \
# 0   WZ62GXAT                        MTT              Cancer
# 1   UK8SV8XM  Live/Dead Viability Assay      Normal; Cancer
# 2   UK8SV8XM  Live/Dead Viability Assay      Normal; Cancer
# 3   JST2FHKJ                   MTT; LDH              Normal
# 4   KT5U49ZB           Neutral Red; MTT              Normal
# 5   95KXTZVR                        LDH              Cancer
# 6   8A3RUDZD                        MTT              Cancer
# 7   8A3RUDZD                        MTT              Cancer
# 8   DUR86VJI              MTS; ATP; LDH              Normal
# 9   DUR86VJI              MTS; ATP; LDH              Normal
# 10  DUR86VJI              MTS; ATP; LDH              Normal
# 11  DUR86VJI              MTS; ATP; LDH              Normal
# 12  DUR86VJI              MTS; ATP; LDH              Normal
# 13  DUR86VJI              MTS; ATP; LDH              Normal
# 14  DUR86VJI              MTS; ATP; LDH              Normal
# 15  DUR86VJI              MTS; ATP; LDH              Normal
# 16  DUR86VJI              MTS; ATP; LDH              Normal
# 17  DUR86VJI              MTS; ATP; LDH              Normal
# 18  DUR86VJI              MTS; ATP; LDH              Normal
# 19  DUR86VJI              MTS; ATP; LDH              Normal
# 20  DUR86VJI              MTS; ATP; LDH              Normal
# 21  DUR86VJI              MTS; ATP; LDH              Normal
# 22  DUR86VJI              MTS; ATP; LDH              Normal
# 23  DUR86VJI              MTS; ATP; LDH              Normal
# 24  DUR86VJI              MTS; ATP; LDH              Normal
# 25  DUR86VJI              MTS; ATP; LDH              Normal
# 26  DUR86VJI              MTS; ATP; LDH              Normal
# 27  DUR86VJI              MTS; ATP; LDH              Normal
# 28  DUR86VJI              MTS; ATP; LDH              Normal
# 29  U5TWM8XC                Trypan blue              Cancer
# 30  U5TWM8XC                Trypan blue              Cancer
# 31  I3MS5H2K             CellTiter-Blue              Cancer
# 32  I3MS5H2K             CellTiter-Blue              Cancer
# 33  I3MS5H2K             CellTiter-Blue              Cancer
# 34  9843ENP3                        MTT              Normal
# 35  9843ENP3                        MTT              Normal
# 36  9843ENP3                        MTT              Normal
# 37  9843ENP3                        MTT              Normal
# 38  W5DHTC2Z                       None              Cancer
#
#                                            cell_organ  \
# 0                                       Adrenal gland
# 1                   Fibroblast (NIH 3T3); Lung (A549)
# 2                   Fibroblast (NIH 3T3); Lung (A549)
# 3                                          Fibroblast
# 4                                 Monocyte-macrophage
# 5                                                Lung
# 6                        Brain (U87MG); Cervix (Hela)
# 7                        Brain (U87MG); Cervix (Hela)
# 8       Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 9       Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 10      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 11      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 12      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 13      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 14      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 15      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 16      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 17      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 18      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 19      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 20      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 21      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 22      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 23      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 24      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 25      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 26      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 27      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 28      Bronchial tube (BEAS-2B); Myeloid (RAW 264.7)
# 29                                        Endothelial
# 30                                        Endothelial
# 31                                             Breast
# 32                                             Breast
# 33                                             Breast
# 34                                         Macrophage
# 35                                         Macrophage
# 36                                         Macrophage
# 37                                         Macrophage
# 38  Neuroblastoma (N2a); Liver (QGY-7703; HepG2; Q...
#
#                                          cell_species  \
# 0                                                 Rat
# 1                       Mouse (NIH 3T3); Human (A549)
# 2                       Mouse (NIH 3T3); Human (A549)
# 3                                               Mouse
# 4                                               Human
# 5                                               Human
# 6                                               Human
# 7                                               Human
# 8                  Human (BEAS-2B); Mouse (RAW 264.7)
# 9                  Human (BEAS-2B); Mouse (RAW 264.7)
# 10                 Human (BEAS-2B); Mouse (RAW 264.7)
# 11                 Human (BEAS-2B); Mouse (RAW 264.7)
# 12                 Human (BEAS-2B); Mouse (RAW 264.7)
# 13                 Human (BEAS-2B); Mouse (RAW 264.7)
# 14                 Human (BEAS-2B); Mouse (RAW 264.7)
# 15                 Human (BEAS-2B); Mouse (RAW 264.7)
# 16                 Human (BEAS-2B); Mouse (RAW 264.7)
# 17                 Human (BEAS-2B); Mouse (RAW 264.7)
# 18                 Human (BEAS-2B); Mouse (RAW 264.7)
# 19                 Human (BEAS-2B); Mouse (RAW 264.7)
# 20                 Human (BEAS-2B); Mouse (RAW 264.7)
# 21                 Human (BEAS-2B); Mouse (RAW 264.7)
# 22                 Human (BEAS-2B); Mouse (RAW 264.7)
# 23                 Human (BEAS-2B); Mouse (RAW 264.7)
# 24                 Human (BEAS-2B); Mouse (RAW 264.7)
# 25                 Human (BEAS-2B); Mouse (RAW 264.7)
# 26                 Human (BEAS-2B); Mouse (RAW 264.7)
# 27                 Human (BEAS-2B); Mouse (RAW 264.7)
# 28                 Human (BEAS-2B); Mouse (RAW 264.7)
# 29                                              Human
# 30                                              Human
# 31                                              Human
# 32                                              Human
# 33                                              Human
# 34                                              Mouse
# 35                                              Mouse
# 36                                              Mouse
# 37                                              Mouse
# 38  Mouse (N2a; RAW264.7; NIH3T3); Human (QGY-7703...
#
#                                             cell_type           ref
# 0                                                PC12      19922763
# 1                                       NIH 3T3; A549  24094173.pdf
# 2                                       NIH 3T3; A549  24094173.pdf
# 3                                             NIH 3T3  24788586.pdf
# 4                                                 HMM  17178155.pdf
# 5                                                A549  23892599.pdf
# 6                                         U87MG; Hela  24462358.pdf
# 7                                         U87MG; Hela  24462358.pdf
# 8                                  BEAS-2B; RAW 264.7  22502734.pdf
# 9                                  BEAS-2B; RAW 264.7  22502734.pdf
# 10                                 BEAS-2B; RAW 264.7  22502734.pdf
# 11                                 BEAS-2B; RAW 264.7  22502734.pdf
# 12                                 BEAS-2B; RAW 264.7  22502734.pdf
# 13                                 BEAS-2B; RAW 264.7  22502734.pdf
# 14                                 BEAS-2B; RAW 264.7  22502734.pdf
# 15                                 BEAS-2B; RAW 264.7  22502734.pdf
# 16                                 BEAS-2B; RAW 264.7  22502734.pdf
# 17                                 BEAS-2B; RAW 264.7  22502734.pdf
# 18                                 BEAS-2B; RAW 264.7  22502734.pdf
# 19                                 BEAS-2B; RAW 264.7  22502734.pdf
# 20                                 BEAS-2B; RAW 264.7  22502734.pdf
# 21                                 BEAS-2B; RAW 264.7  22502734.pdf
# 22                                 BEAS-2B; RAW 264.7  22502734.pdf
# 23                                 BEAS-2B; RAW 264.7  22502734.pdf
# 24                                 BEAS-2B; RAW 264.7  22502734.pdf
# 25                                 BEAS-2B; RAW 264.7  22502734.pdf
# 26                                 BEAS-2B; RAW 264.7  22502734.pdf
# 27                                 BEAS-2B; RAW 264.7  22502734.pdf
# 28                                 BEAS-2B; RAW 264.7  22502734.pdf
# 29                                            ECV-304  22776829.pdf
# 30                                            ECV-304  22776829.pdf
# 31                                              MCF-7  25630810.pdf
# 32                                              MCF-7  25630810.pdf
# 33                                              MCF-7  25630810.pdf
# 34                                          RAW 264.7  22393292.pdf
# 35                                          RAW 264.7  22393292.pdf
# 36                                          RAW 264.7  22393292.pdf
# 37                                          RAW 264.7  22393292.pdf
# 38  N2a; QGY-7703; HepG2; RAW264.7; NIH3T3; QSG-77...  26773667.pdf

# %% [markdown]
# # Tox data extraction results

# %%
import datetime
from pytz import timezone

now = datetime.datetime.now(timezone('Asia/Seoul'))
now = now.strftime("%Y%m%d_%H%M%S")
o = os.path.join(output_folder, "tox_gtp_output_" + now + ".xlsx")
all_tox_df.to_excel(o)
print("saved as " + o + ".")
# Out:
# output_HEY20241019-Eunyong Ha-Claude 3.5 sonnet-Ha1/tox_gtp_output_20241020_005451.xlsx로 저장되었습니다.

# %%
# 마지막 셀에 추가
notebook_end_time = time.time()
print(f"total running time: {notebook_end_time - notebook_start_time}sec")
# Out:
# 노트북 전체 실행 시간: 676.0091426372528초

# %% [markdown]
# # Tokens and cost

# %%
cost_list = []
for key, value in openai_cb.items():
    #print(value.total_cost)
    cost_dict = {}
    cost_dict["Date Time"] = key
    cost_dict["Total tokens"] = value.total_tokens
    cost_dict["Total cost ($)"] = value.total_cost
    cost_list.append(cost_dict)

cost_df = pd.DataFrame(cost_list)
sums = cost_df.select_dtypes(include='number').sum()
sums_dict = {"Date Time": "Total", "Total tokens": sums["Total tokens"], "Total cost ($)": sums["Total cost ($)"]}

# %%
cost_df = pd.concat([cost_df, pd.DataFrame([sums_dict])])
cost_df
# Out:
#            Date Time  Total tokens  Total cost ($)
# 0    20241020_004434           0.0             0.0
# 1    20241020_004436           0.0             0.0
# 2    20241020_004437           0.0             0.0
# 3    20241020_004439           0.0             0.0
# 4    20241020_004441           0.0             0.0
# ..               ...           ...             ...
# 280  20241020_005440           0.0             0.0
# 281  20241020_005443           0.0             0.0
# 282  20241020_005446           0.0             0.0
# 283  20241020_005451           0.0             0.0
# 0              Total           0.0             0.0
#
# [285 rows x 3 columns]

# %%
import datetime
from pytz import timezone

now = datetime.datetime.now(timezone('Asia/Seoul'))
now = now.strftime("%Y%m%d_%H%M%S")
o = os.path.join(output_folder, "token_and_cost_" + now + ".xlsx")
cost_df.to_excel(o)
print("saved as " + o + ".")
# Out:
# output_HEY20241019-Eunyong Ha-Claude 3.5 sonnet-Ha1/token_and_cost_20241020_005451.xlsx로 저장되었습니다.

# %%
# 마지막 셀에 추가
notebook_end_time = time.time()
print(f"total running time: {notebook_end_time - notebook_start_time}sec")
# Out:
# 노트북 전체 실행 시간: 676.5923361778259초
